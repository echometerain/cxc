# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: mplcursors in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (0.6)
# Requirement already satisfied: pandas in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: seaborn in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: scipy in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 5)) (1.15.2)
# Requirement already satisfied: jupyterlab in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 6)) (4.3.5)
# Requirement already satisfied: pillow in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 7)) (11.1.0)
# Requirement already satisfied: voila in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 8)) (0.5.8)
# Requirement already satisfied: python-fasthtml in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: matplotlib in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: tilemapbase in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 11)) (0.4.7)
# Requirement already satisfied: jupyter-collaboration in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 12)) (3.1.0)
# Requirement already satisfied: openpyxl in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 13)) (3.1.5)
# Requirement already satisfied: scikit-learn in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 14)) (1.6.1)
# Requirement already satisfied: ipympl in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 15)) (0.9.6)
# Requirement already satisfied: geopandas in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 16)) (1.0.1)
# Requirement already satisfied: thefuzz in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from -r requirements.txt (line 17)) (0.22.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: async-lru>=1.0.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (3.1.5)
# Requirement already satisfied: jupyter-core in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: packaging in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: setuptools>=40.8.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (75.8.0)
# Requirement already satisfied: tornado>=6.2.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (6.4.2)
# Requirement already satisfied: traitlets in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 6)) (5.14.3)
# Requirement already satisfied: jupyter-client<9,>=7.4.4 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from voila->-r requirements.txt (line 8)) (8.6.3)
# Requirement already satisfied: nbclient>=0.4.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from voila->-r requirements.txt (line 8)) (0.10.2)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from voila->-r requirements.txt (line 8)) (7.16.6)
# Requirement already satisfied: websockets>=9.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from voila->-r requirements.txt (line 8)) (15.0)
# Requirement already satisfied: fastcore>=1.7.18 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from python-fasthtml->-r requirements.txt (line 9)) (1.7.29)
# Requirement already satisfied: starlette>0.33 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from python-fasthtml->-r requirements.txt (line 9)) (0.45.3)
# Requirement already satisfied: oauthlib in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from python-fasthtml->-r requirements.txt (line 9)) (3.2.2)
# Requirement already satisfied: itsdangerous in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from python-fasthtml->-r requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: uvicorn>=0.30 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml->-r requirements.txt (line 9)) (0.34.0)
# Requirement already satisfied: fastlite>=0.1.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from python-fasthtml->-r requirements.txt (line 9)) (0.1.1)
# Requirement already satisfied: python-multipart in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from python-fasthtml->-r requirements.txt (line 9)) (0.0.20)
# Requirement already satisfied: beautifulsoup4 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from python-fasthtml->-r requirements.txt (line 9)) (4.13.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 10)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 10)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 10)) (3.2.1)
# Requirement already satisfied: requests in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from tilemapbase->-r requirements.txt (line 11)) (2.32.3)
# Requirement already satisfied: jupyter-collaboration-ui>=1.1.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-collaboration->-r requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: jupyter-docprovider>=1.1.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-collaboration->-r requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: jupyter-server-ydoc>=1.1.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-collaboration->-r requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: et-xmlfile in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from openpyxl->-r requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from scikit-learn->-r requirements.txt (line 14)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from scikit-learn->-r requirements.txt (line 14)) (3.5.0)
# Requirement already satisfied: ipython<9 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipympl->-r requirements.txt (line 15)) (8.32.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipympl->-r requirements.txt (line 15)) (8.1.5)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from geopandas->-r requirements.txt (line 16)) (0.10.0)
# Requirement already satisfied: pyproj>=3.3.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from geopandas->-r requirements.txt (line 16)) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from geopandas->-r requirements.txt (line 16)) (2.0.7)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from thefuzz->-r requirements.txt (line 17)) (3.12.1)
# Requirement already satisfied: apswutils>=0.0.2 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from fastlite>=0.1.1->python-fasthtml->-r requirements.txt (line 9)) (0.0.2)
# Requirement already satisfied: anyio in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: certifi in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 6)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 6)) (1.0.7)
# Requirement already satisfied: idna in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 6)) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->-r requirements.txt (line 6)) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 6)) (1.8.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: psutil in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 6)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 6)) (26.2.1)
# Requirement already satisfied: decorator in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipython<9->ipympl->-r requirements.txt (line 15)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipython<9->ipympl->-r requirements.txt (line 15)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipython<9->ipympl->-r requirements.txt (line 15)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipython<9->ipympl->-r requirements.txt (line 15)) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipython<9->ipympl->-r requirements.txt (line 15)) (2.19.1)
# Requirement already satisfied: stack_data in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipython<9->ipympl->-r requirements.txt (line 15)) (0.6.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 15)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 15)) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jinja2>=3.0.3->jupyterlab->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-core->jupyterlab->-r requirements.txt (line 6)) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server-ydoc>=1.1.0->jupyter-collaboration->-r requirements.txt (line 12)) (4.23.0)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.7.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server-ydoc>=1.1.0->jupyter-collaboration->-r requirements.txt (line 12)) (0.9.3)
# Requirement already satisfied: jupyter-ydoc!=3.0.0,!=3.0.1,<4.0.0,>=2.1.2 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server-ydoc>=1.1.0->jupyter-collaboration->-r requirements.txt (line 12)) (3.0.3)
# Requirement already satisfied: pycrdt in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server-ydoc>=1.1.0->jupyter-collaboration->-r requirements.txt (line 12)) (0.12.8)
# Requirement already satisfied: pycrdt-websocket<0.16.0,>=0.15.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-server-ydoc>=1.1.0->jupyter-collaboration->-r requirements.txt (line 12)) (0.15.4)
# Requirement already satisfied: babel>=2.10 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 6)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: bleach!=5.0.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila->-r requirements.txt (line 8)) (6.2.0)
# Requirement already satisfied: defusedxml in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from nbconvert<8,>=6.4.5->voila->-r requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from nbconvert<8,>=6.4.5->voila->-r requirements.txt (line 8)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from nbconvert<8,>=6.4.5->voila->-r requirements.txt (line 8)) (3.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from nbconvert<8,>=6.4.5->voila->-r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: six>=1.5 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from requests->tilemapbase->-r requirements.txt (line 11)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from requests->tilemapbase->-r requirements.txt (line 11)) (2.3.0)
# Requirement already satisfied: click>=7.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from uvicorn>=0.30->uvicorn[standard]>=0.30->python-fasthtml->-r requirements.txt (line 9)) (8.1.8)
# Requirement already satisfied: httptools>=0.6.3 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml->-r requirements.txt (line 9)) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml->-r requirements.txt (line 9)) (1.0.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml->-r requirements.txt (line 9)) (6.0.2)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml->-r requirements.txt (line 9)) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml->-r requirements.txt (line 9)) (1.0.4)
# Requirement already satisfied: soupsieve>1.2 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from beautifulsoup4->python-fasthtml->-r requirements.txt (line 9)) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from beautifulsoup4->python-fasthtml->-r requirements.txt (line 9)) (4.12.2)
# Requirement already satisfied: sniffio>=1.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from anyio->httpx>=0.25.0->jupyterlab->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: apsw in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from apswutils>=0.0.2->fastlite>=0.1.1->python-fasthtml->-r requirements.txt (line 9)) (3.49.0.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: webencodings in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila->-r requirements.txt (line 8)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila->-r requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jedi>=0.16->ipython<9->ipympl->-r requirements.txt (line 15)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyter-server-ydoc>=1.1.0->jupyter-collaboration->-r requirements.txt (line 12)) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyter-server-ydoc>=1.1.0->jupyter-collaboration->-r requirements.txt (line 12)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyter-server-ydoc>=1.1.0->jupyter-collaboration->-r requirements.txt (line 12)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyter-server-ydoc>=1.1.0->jupyter-collaboration->-r requirements.txt (line 12)) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (3.2.1)
# Requirement already satisfied: rfc3339-validator in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from pexpect>4.3->ipython<9->ipympl->-r requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<9->ipympl->-r requirements.txt (line 15)) (0.2.13)
# Requirement already satisfied: sqlite-anyio<0.3.0,>=0.2.3 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from pycrdt-websocket<0.16.0,>=0.15.0->jupyter-server-ydoc>=1.1.0->jupyter-collaboration->-r requirements.txt (line 12)) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from stack_data->ipython<9->ipympl->-r requirements.txt (line 15)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from stack_data->ipython<9->ipympl->-r requirements.txt (line 15)) (3.0.0)
# Requirement already satisfied: pure-eval in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from stack_data->ipython<9->ipympl->-r requirements.txt (line 15)) (0.2.3)
# Requirement already satisfied: fqdn in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: uri-template in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.17.1)
# Requirement already satisfied: pycparser in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (2.9.0.20241206)

# %%
# %matplotlib widget
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mplcursors import cursor
import matplotlib
import textwrap

df = pd.read_excel("SAP Datasets.xlsx")
df = df.dropna(how="all", subset=map(lambda n:str(n), range(2000, 2024))) # remove statistic if all time-series columns are null
df = df.drop(columns=["Country Code", "short description", "long description", "Indicator Code", "Unit of measure"]) # irrelevent / null columns
df
# Out:
#        Country Name                            Indicator Name  \
# 0             Aruba           Control of Corruption: Estimate
# 2       Afghanistan           Control of Corruption: Estimate
# 4            Angola           Control of Corruption: Estimate
# 5           Albania           Control of Corruption: Estimate
# 6           Andorra           Control of Corruption: Estimate
# ...             ...                                       ...
# 23135         Samoa  Urban population (% of total population)
# 23137   Yemen, Rep.  Urban population (% of total population)
# 23138  South Africa  Urban population (% of total population)
# 23139        Zambia  Urban population (% of total population)
# 23140      Zimbabwe  Urban population (% of total population)
#
#                                       Topic       2000    2001       2002  \
# 0      Public Sector: Policy & institutions        NaN     NaN        NaN
# 2      Public Sector: Policy & institutions  -1.271724     NaN  -1.251137
# 4      Public Sector: Policy & institutions  -1.197514     NaN  -1.155493
# 5      Public Sector: Policy & institutions  -0.855564     NaN  -0.845341
# 6      Public Sector: Policy & institutions   1.313404     NaN   1.310744
# ...                                     ...        ...     ...        ...
# 23135   Environment: Density & urbanization  21.977000  22.068  21.941000
# 23137   Environment: Density & urbanization  26.267000  26.787  27.315000
# 23138   Environment: Density & urbanization  56.891000  57.368  57.898000
# 23139   Environment: Density & urbanization  34.802000  35.002  35.475000
# 23140   Environment: Density & urbanization  33.758000  34.170  34.585000
#
#             2003       2004       2005       2006  ...       2014       2015  \
# 0            NaN   1.165965   1.269663   1.251313  ...   1.014232   1.248461
# 2      -1.344180  -1.350647  -1.447252  -1.446292  ...  -1.364743  -1.354240
# 4      -1.335463  -1.377569  -1.323182  -1.241038  ...  -1.457798  -1.427323
# 5      -0.853787  -0.723732  -0.813264  -0.790545  ...  -0.586141  -0.544385
# 6       1.332790   1.119150   1.269663   1.251313  ...   1.220709   1.151811
# ...          ...        ...        ...        ...  ...        ...        ...
# 23135  21.698000  21.457000  21.218000  20.981000  ...  19.149000  18.914000
# 23137  27.849000  28.390000  28.936000  29.490000  ...  34.165000  34.777000
# 23138  58.446000  58.993000  59.536000  60.077000  ...  64.312000  64.828000
# 23139  35.951000  36.430000  36.911000  37.395000  ...  41.382000  41.907000
# 23140  34.479000  34.294000  34.110000  33.926000  ...  32.504000  32.385000
#
#             2016       2017       2018       2019       2020       2021  \
# 0       1.232735   1.239377   1.207429   1.174703   1.199392   0.801611
# 2      -1.540353  -1.531910  -1.502881  -1.419499  -1.493700  -1.152327
# 4      -1.483337  -1.444333  -1.199251  -1.058418  -0.938673  -0.651610
# 5      -0.471469  -0.480891  -0.545840  -0.563900  -0.572924  -0.576536
# 6       1.159556   1.171758   1.179166   1.176592   1.266005   1.279872
# ...          ...        ...        ...        ...        ...        ...
# 23135  18.681000  18.452000  18.243000  18.056000  17.889000  17.742000
# 23137  35.394000  36.016000  36.642000  37.273000  37.908000  38.546000
# 23138  65.341000  65.850000  66.355000  66.856000  67.354000  67.847000
# 23139  42.438000  42.976000  43.521000  44.072000  44.629000  45.192000
# 23140  32.296000  32.237000  32.209000  32.210000  32.242000  32.303000
#
#             2022    2023
# 0       0.756785     NaN
# 2      -1.183776     NaN
# 4      -0.601941     NaN
# 5      -0.407876     NaN
# 6       1.270204     NaN
# ...          ...     ...
# 23135  17.616000  17.508
# 23137  39.188000  39.831
# 23138  68.335000  68.819
# 23139  45.761000  46.335
# 23140  32.395000  32.517
#
# [16699 rows x 27 columns]

# %%
# sns.set_theme(rc={'figure.figsize':(20,20)})
fig1, ax1 = plt.subplots()

# plot poverty rates from known indicators
UNDP = np.log10(df.loc[df["Indicator Name"] == "Multidimensional poverty headcount ratio (UNDP) (% of population)"]
         .set_index("Country Name").iloc[:,7:]
         .apply(lambda row: row[row.last_valid_index()], axis=1)
         .rename("UNDP")+1)

WB = np.log10(df.loc[df["Indicator Name"] == "Multidimensional poverty headcount ratio (World Bank) (% of population)"]
        .set_index("Country Name").iloc[:,7:]
        .apply(lambda row: row[row.last_valid_index()], axis=1)
        .rename("WB")+1)

UNDP_aligned, WB_aligned = UNDP.align(WB, join='inner')
UNDP_clean = UNDP_aligned.dropna()
WB_clean = WB_aligned.dropna()

plot1 = sns.scatterplot(x=UNDP_clean, y=WB_clean, legend=False, ax=ax1)

# for country in UNDP_clean.index:
#     ax.text(x=(UNDP_clean[country]+0.01), 
#             y=(WB_clean[country]-0.004), 
#             s=country, 
#             fontsize=8, 
#             alpha=0.7)
cursor(plot1, hover=True).connect("add", lambda sel: sel.annotation.set_text(WB_clean.index[sel.index]))
plt.title("log(%) of population in poverty, World Bank vs UNDP")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# show all indicators
df["Indicator Name"].unique()
# Out:
# array(['Control of Corruption: Estimate',
#        'Multilateral debt service (% of public and publicly guaranteed debt service)',
#        'Access to clean fuels and technologies for cooking, rural (% of rural population)',
#        'Access to clean fuels and technologies for cooking, urban (% of urban population)',
#        'Access to clean fuels and technologies for cooking (% of population)',
#        'Access to electricity, rural (% of rural population)',
#        'Access to electricity, urban (% of urban population)',
#        'Access to electricity (% of population)',
#        'Compensation of employees (current LCU)',
#        'Compensation of employees (% of expense)',
#        'Adjusted savings: education expenditure (current US$)',
#        'Adjusted net national income per capita (current US$)',
#        'Terms of trade adjustment (constant LCU)',
#        'Adequacy of social protection and labor programs (% of total welfare of beneficiary households)',
#        'Adequacy of unemployment benefits and ALMP (% of total welfare of beneficiary households)',
#        'Adequacy of social safety net programs (% of total welfare of beneficiary households)',
#        'Adequacy of social insurance programs (% of total welfare of beneficiary households)',
#        'Political Stability and Absence of Violence/Terrorism: Estimate',
#        'Literacy rate, youth female (% of females ages 15-24)',
#        'Literacy rate, youth (ages 15-24), gender parity index (GPI)',
#        'Literacy rate, youth male (% of males ages 15-24)',
#        'Literacy rate, youth total (% of people ages 15-24)',
#        'Literacy rate, adult female (% of females ages 15 and above)',
#        'Literacy rate, adult male (% of males ages 15 and above)',
#        'Literacy rate, adult total (% of people ages 15 and above)',
#        'Compulsory education, duration (years)',
#        'School enrollment, primary (gross), gender parity index (GPI)',
#        'School enrollment, secondary (gross), gender parity index (GPI)',
#        'School enrollment, tertiary (gross), gender parity index (GPI)',
#        'Children out of school, primary',
#        'Children out of school, primary, female',
#        'Children out of school, female (% of female primary school age)',
#        'Children out of school, primary, male',
#        'Children out of school, male (% of male primary school age)',
#        'Children out of school (% of primary school age)',
#        'Adolescents out of school, female (% of female lower secondary school age)',
#        'Adolescents out of school, male (% of male lower secondary school age)',
#        'Adolescents out of school (% of lower secondary school age)',
#        'Expenditure on primary education (% of government expenditure on education)',
#        'Expenditure on secondary education (% of government expenditure on education)',
#        'Expenditure on tertiary education (% of government expenditure on education)',
#        'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)',
#        'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)',
#        'Cause of death, by injury (% of total)',
#        'Cause of death, by non-communicable diseases (% of total)',
#        'People using at least basic drinking water services (% of population)',
#        'People using safely managed drinking water services (% of population)',
#        'Community health workers (per 1,000 people)',
#        'Pregnant women receiving prenatal care (%)',
#        'People using at least basic sanitation services (% of population)',
#        'Births attended by skilled health staff (% of total)',
#        'Current health expenditure (% of GDP)',
#        'Current health expenditure per capita (current US$)',
#        'Proportion of people living below 50 percent of median income (%)',
#        'Multidimensional poverty headcount ratio (UNDP) (% of population)',
#        'Multidimensional poverty headcount ratio (World Bank) (% of population)',
#        'Employers, female (% of female employment) (modeled ILO estimate)',
#        'Employers, male (% of male employment) (modeled ILO estimate)',
#        'Employers, total (% of total employment) (modeled ILO estimate)',
#        'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
#        'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
#        'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
#        'Children in employment, study and work, female (% of female children in employment, ages 7-14)',
#        'Children in employment, study and work, male (% of male children in employment, ages 7-14)',
#        'Children in employment, study and work (% of children in employment, ages 7-14)',
#        'Children in employment, work only, female (% of female children in employment, ages 7-14)',
#        'Children in employment, work only, male (% of male children in employment, ages 7-14)',
#        'Children in employment, work only (% of children in employment, ages 7-14)',
#        'Children in employment, total (% of children ages 7-14)',
#        'Unemployment with advanced education (% of total labor force with advanced education)',
#        'Unemployment with basic education (% of total labor force with basic education)',
#        'Unemployment with intermediate education (% of total labor force with intermediate education)',
#        'Unemployment, total (% of total labor force) (national estimate)',
#        'Children in employment, wage workers, female (% of female children in employment, ages 7-14)',
#        'Children in employment, wage workers, male (% of male children in employment, ages 7-14)',
#        'Children in employment, wage workers (% of children in employment, ages 7-14)',
#        'International migrant stock, total',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Birth rate, crude (per 1,000 people)',
#        'Wanted fertility rate (births per woman)',
#        'Women who were first married by age 15 (% of women ages 20-24)',
#        'Women who were first married by age 18 (% of women ages 20-24)',
#        'Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)',
#        'Age dependency ratio (% of working-age population)',
#        'Age dependency ratio, old (% of working-age population)',
#        'Age dependency ratio, young (% of working-age population)',
#        'Population, total', 'Urban population (% of total population)'],
#       dtype=object)

# %%
sqrt = ['Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)']
nolog = [
    'Cause of death, by non-communicable diseases (% of total)',
    'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
    'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
    'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
]
square = [
    'Access to clean fuels and technologies for cooking, rural (% of rural population)',
    'Access to clean fuels and technologies for cooking, urban (% of urban population)',
    'Access to clean fuels and technologies for cooking (% of population)',
    'Access to electricity, rural (% of rural population)',
    'Access to electricity, urban (% of urban population)',
    'Access to electricity (% of population)',
    
    'Births attended by skilled health staff (% of total)',
    'Children in employment, study and work, female (% of female children in employment, ages 7-14)',
    'Children in employment, study and work, male (% of male children in employment, ages 7-14)',
    'Children in employment, study and work (% of children in employment, ages 7-14)',
    'Children in employment, total (% of children ages 7-14)',
    'Children in employment, wage workers, male (% of male children in employment, ages 7-14)',
    'Children in employment, wage workers (% of children in employment, ages 7-14)',
    'Literacy rate, youth female (% of females ages 15-24)',
    'Literacy rate, youth (ages 15-24), gender parity index (GPI)',
    'Literacy rate, youth male (% of males ages 15-24)',
    'Literacy rate, youth total (% of people ages 15-24)',
    'Literacy rate, adult female (% of females ages 15 and above)',
    'Literacy rate, adult male (% of males ages 15 and above)',
    'Literacy rate, adult total (% of people ages 15 and above)',
    'People using at least basic drinking water services (% of population)',
    'People using safely managed drinking water services (% of population)',
    'People using at least basic sanitation services (% of population)',
    'Urban population (% of total population)',
]

# %%
epsilon = 0.01 # add a little offset because you can't log 0

# Clean Data
df2 = df.copy()
# row[row.last_valid_index()] # originally we were grabbing the last non-nan cell
years = list(map(lambda n:str(n), list(range(2000, 2024))))
summaries = ["mean_x", "mean_dx", "mean_d2x"]

# take first and second derivative of the data
df2["mean_x"] = df2[years].apply(lambda row: row.mean(), axis=1)
df2["mean_dx"] = df2[years].apply(lambda row: np.diff(row.dropna(), n=1).mean(), axis=1)
df2["mean_d2x"] = df2[years].apply(lambda row: np.diff(row.dropna(), n=2).mean(), axis=1)

# drop time series data
df2 = df2.drop(columns=years)

# use pseudo-log to normalize most statistics
pseudo_log = lambda x: np.arcsinh(x/2)/np.log(10)
allnolog = sqrt + nolog + square
logged = df2.groupby("Indicator Name").filter(lambda x: x["mean_x"].min() > 0 and x["Indicator Name"].unique()[0] not in allnolog)
df2.update(logged[summaries].replace({0: epsilon}).apply(lambda col:pseudo_log(col))) # DIRECTLY CHANGES OBJECT!!!

# use pseudo-log to normalize trade surplus / deficit
logged2 = df2.loc[df2["Indicator Name"] == "Terms of trade adjustment (constant LCU)"] # monitary statistics are usually exponential
df2.update(logged2[summaries].apply(lambda col:pseudo_log(col))) # DIRECTLY CHANGES OBJECT!!!

# use square to normalize left-skewed distributions
squared = df2.groupby("Indicator Name").filter(lambda x: x["Indicator Name"].unique()[0] in square)
df2.update((squared["mean_x"] / 100)**2) # DIRECTLY CHANGES OBJECT!!!

# generate contengency table based on normalized statistics
pivot = df2.pivot(index="Country Name", columns="Indicator Name")
df2 = pivot["mean_x"].join(pivot["mean_dx"], rsuffix=", FIRST DERIVATIVE").join(pivot["mean_d2x"], rsuffix=", SECOND DERIVATIVE")
def replacer(col):
    mean = col.mean()
    std = col.std()
    # np.random.normal(mean, std) # originally we replaced the nan's with representitive statistics that had the same mean & std
    # replace with mean if cell is nan or an outlier (z-score > 2.5)
    return col.transform(lambda x: mean if (np.isnan(x) or abs((x - mean)/std) >= 2.5) else x)
    
# delete row or column if (amount of data / 2) == nan
nan_col = df2.isna().sum().sort_values()
nan_idx = df2.isna().sum(axis=1).sort_values()
nan_col = nan_col.loc[nan_col > 130]
nan_idx = nan_idx[nan_idx > 130]
drop_col = ["Multidimensional poverty headcount ratio (World Bank) (% of population)", "Multidimensional poverty headcount ratio (UNDP) (% of population)"]
df2 = df2.drop(columns=(list(nan_col.index) + drop_col), index=nan_idx.index).apply(replacer)

# thing = df2.isnull().any()
# thing[thing == True]
print(df2.isnull().values.any()) 
df2

# df2.columns.to_list()
# pivot["mean_d2x"]
# Out:
# /tmp/ipykernel_3882096/2277892617.py:11: RuntimeWarning: Mean of empty slice.
#   df2["mean_dx"] = df2[years].apply(lambda row: np.diff(row.dropna(), n=1).mean(), axis=1)
# /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /tmp/ipykernel_3882096/2277892617.py:12: RuntimeWarning: Mean of empty slice.
#   df2["mean_d2x"] = df2[years].apply(lambda row: np.diff(row.dropna(), n=2).mean(), axis=1)
# /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# False
# Indicator Name              Access to clean fuels and technologies for cooking (% of population)  \
# Country Name
# Afghanistan                                                          0.044448
# Africa Western and Central                                           0.009573
# Albania                                                              0.425189
# Algeria                                                              0.978207
# Angola                                                               0.205406
# ...                                                                       ...
# West Bank and Gaza                                                   0.522369
# World                                                                0.356941
# Yemen, Rep.                                                          0.317777
# Zambia                                                               0.019588
# Zimbabwe                                                             0.096883
#
# Indicator Name              Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# Country Name
# Afghanistan                                                          0.006470
# Africa Western and Central                                           0.000540
# Albania                                                              0.205899
# Algeria                                                              0.943897
# Angola                                                               0.005763
# ...                                                                       ...
# West Bank and Gaza                                                   0.439294
# World                                                                0.120514
# Yemen, Rep.                                                          0.159513
# Zambia                                                               0.000436
# Zimbabwe                                                             0.002925
#
# Indicator Name              Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# Country Name
# Afghanistan                                                          0.425189
# Africa Western and Central                                           0.041347
# Albania                                                              0.706623
# Algeria                                                              0.997740
# Angola                                                               0.607485
# ...                                                                       ...
# West Bank and Gaza                                                   0.636055
# World                                                                0.680017
# Yemen, Rep.                                                          0.858644
# Zambia                                                               0.108484
# Zimbabwe                                                             0.669017
#
# Indicator Name              Access to electricity (% of population)  \
# Country Name
# Afghanistan                                                0.325942
# Africa Western and Central                                 0.197104
# Albania                                                    0.994529
# Algeria                                                    0.981995
# Angola                                                     0.131674
# ...                                                             ...
# West Bank and Gaza                                         0.994269
# World                                                      0.718562
# Yemen, Rep.                                                0.387154
# Zambia                                                     0.086871
# Zimbabwe                                                   0.160418
#
# Indicator Name              Access to electricity, rural (% of rural population)  \
# Country Name
# Afghanistan                                                          0.316406
# Africa Western and Central                                           0.045300
# Albania                                                              0.999131
# Algeria                                                              0.959804
# Angola                                                               0.001537
# ...                                                                       ...
# West Bank and Gaza                                                   0.986222
# World                                                                0.556290
# Yemen, Rep.                                                          0.226836
# Zambia                                                               0.005929
# Zimbabwe                                                             0.030443
#
# Indicator Name              Access to electricity, urban (% of urban population)  \
# Country Name
# Afghanistan                                                          0.782840
# Africa Western and Central                                           0.605991
# Albania                                                              0.975285
# Algeria                                                              0.993142
# Angola                                                               0.382139
# ...                                                                       ...
# West Bank and Gaza                                                   0.997132
# World                                                                0.924997
# Yemen, Rep.                                                          0.878213
# Zambia                                                               0.376409
# Zimbabwe                                                             0.733629
#
# Indicator Name              Adjusted net national income per capita (current US$)  \
# Country Name
# Afghanistan                                                          2.702385
# Africa Western and Central                                           3.060213
# Albania                                                              3.504623
# Algeria                                                              3.460934
# Angola                                                               3.186075
# ...                                                                       ...
# West Bank and Gaza                                                   3.536888
# World                                                                3.871600
# Yemen, Rep.                                                          2.882514
# Zambia                                                               2.917476
# Zimbabwe                                                             2.866943
#
# Indicator Name              Adjusted savings: education expenditure (current US$)  \
# Country Name
# Afghanistan                                                          8.695612
# Africa Western and Central                                           9.086672
# Albania                                                              8.530759
# Algeria                                                              9.793755
# Angola                                                               9.310128
# ...                                                                       ...
# West Bank and Gaza                                                   8.679404
# World                                                                9.086672
# Yemen, Rep.                                                          8.927542
# Zambia                                                               8.676742
# Zimbabwe                                                             8.444791
#
# Indicator Name              Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# Country Name
# Afghanistan                                                          2.057893
# Africa Western and Central                                           2.087651
# Albania                                                              1.236911
# Algeria                                                              1.036264
# Angola                                                               2.199554
# ...                                                                       ...
# West Bank and Gaza                                                   1.761598
# World                                                                1.709903
# Yemen, Rep.                                                          1.893741
# Zambia                                                               2.127874
# Zimbabwe                                                             2.013007
#
# Indicator Name              Adolescents out of school (% of lower secondary school age)  \
# Country Name
# Afghanistan                                                          0.922540
# Africa Western and Central                                           0.922540
# Albania                                                              0.438939
# Algeria                                                              0.488767
# Angola                                                               1.325245
# ...                                                                       ...
# West Bank and Gaza                                                   0.965890
# World                                                                0.922540
# Yemen, Rep.                                                          1.594273
# Zambia                                                               0.922540
# Zimbabwe                                                             1.257741
#
# Indicator Name              ...  \
# Country Name                ...
# Afghanistan                 ...
# Africa Western and Central  ...
# Albania                     ...
# Algeria                     ...
# Angola                      ...
# ...                         ...
# West Bank and Gaza          ...
# World                       ...
# Yemen, Rep.                 ...
# Zambia                      ...
# Zimbabwe                    ...
#
# Indicator Name              Terms of trade adjustment (constant LCU), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                          8.713281
# Africa Western and Central                                           1.445672
# Albania                                                              9.120155
# Algeria                                                              9.859411
# Angola                                                              -9.580800
# ...                                                                       ...
# West Bank and Gaza                                                   6.134218
# World                                                                1.445672
# Yemen, Rep.                                                         -8.638857
# Zambia                                                               8.918997
# Zimbabwe                                                             8.058335
#
# Indicator Name              Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.000263
# Africa Western and Central                                          -0.008555
# Albania                                                             -0.033684
# Algeria                                                             -0.003684
# Angola                                                              -0.107368
# ...                                                                       ...
# West Bank and Gaza                                                  -0.000168
# World                                                               -0.026870
# Yemen, Rep.                                                          0.000842
# Zambia                                                              -0.012105
# Zimbabwe                                                            -0.050526
#
# Indicator Name              Unemployment with advanced education (% of total labor force with advanced education), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.796659
# Africa Western and Central                                          -0.051611
# Albania                                                             -0.058822
# Algeria                                                             -0.051611
# Angola                                                               0.393280
# ...                                                                       ...
# West Bank and Gaza                                                  -0.062529
# World                                                               -0.051611
# Yemen, Rep.                                                         -0.051611
# Zambia                                                              -0.101312
# Zimbabwe                                                            -0.260459
#
# Indicator Name              Unemployment with basic education (% of total labor force with basic education), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.684209
# Africa Western and Central                                          -0.012649
# Albania                                                             -0.061096
# Algeria                                                             -0.012649
# Angola                                                              -0.012649
# ...                                                                       ...
# West Bank and Gaza                                                  -0.155708
# World                                                               -0.012649
# Yemen, Rep.                                                         -0.012649
# Zambia                                                               0.422493
# Zimbabwe                                                             0.124939
#
# Indicator Name              Unemployment with intermediate education (% of total labor force with intermediate education), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.683001
# Africa Western and Central                                          -0.002303
# Albania                                                             -0.021380
# Algeria                                                             -0.002303
# Angola                                                               0.374428
# ...                                                                       ...
# West Bank and Gaza                                                  -0.115051
# World                                                               -0.002303
# Yemen, Rep.                                                         -0.002303
# Zambia                                                              -0.144131
# Zimbabwe                                                             0.336266
#
# Indicator Name              Unemployment, total (% of total labor force) (national estimate), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.266725
# Africa Western and Central                                          -0.560774
# Albania                                                              0.001998
# Algeria                                                              0.057754
# Angola                                                               0.002892
# ...                                                                       ...
# West Bank and Gaza                                                  -0.130765
# World                                                               -0.025190
# Yemen, Rep.                                                         -0.148137
# Zambia                                                              -0.047115
# Zimbabwe                                                            -0.023386
#
# Indicator Name              Urban population (% of total population), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                          0.010273
# Africa Western and Central                                          -0.000902
# Albania                                                              0.005000
# Algeria                                                             -0.013500
# Angola                                                              -0.026364
# ...                                                                       ...
# West Bank and Gaza                                                   0.003227
# World                                                               -0.000454
# Yemen, Rep.                                                          0.005591
# Zambia                                                               0.017000
# Zimbabwe                                                            -0.013182
#
# Indicator Name              Wage and salaried workers, female (% of female employment) (modeled ILO estimate), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                          0.011234
# Africa Western and Central                                           0.023686
# Albania                                                             -0.009037
# Algeria                                                             -0.021531
# Angola                                                               0.044966
# ...                                                                       ...
# West Bank and Gaza                                                   0.010404
# World                                                               -0.012473
# Yemen, Rep.                                                          0.073033
# Zambia                                                               0.019565
# Zimbabwe                                                             0.026693
#
# Indicator Name              Wage and salaried workers, male (% of male employment) (modeled ILO estimate), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.035012
# Africa Western and Central                                          -0.019933
# Albania                                                             -0.021626
# Algeria                                                             -0.000328
# Angola                                                              -0.028461
# ...                                                                       ...
# West Bank and Gaza                                                  -0.004707
# World                                                               -0.026413
# Yemen, Rep.                                                          0.020520
# Zambia                                                               0.023079
# Zimbabwe                                                             0.014262
#
# Indicator Name              Wage and salaried workers, total (% of total employment) (modeled ILO estimate), SECOND DERIVATIVE
# Country Name
# Afghanistan                                                          0.025683
# Africa Western and Central                                          -0.000189
# Albania                                                             -0.016342
# Algeria                                                             -0.004633
# Angola                                                               0.013800
# ...                                                                       ...
# West Bank and Gaza                                                   0.003398
# World                                                               -0.020991
# Yemen, Rep.                                                          0.007065
# Zambia                                                               0.030909
# Zimbabwe                                                             0.023292
#
# [221 rows x 200 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

fig2, ax2 = plt.subplots(figsize=(12, 8))

# Do PCA
Scaled_data = StandardScaler().fit_transform(df2.T) # PCA expects the features to be on the index
pca = PCA(n_components=4) # we don't be using the last two
x = pca.fit_transform(Scaled_data)
scores = np.matmul(Scaled_data.T, x).T # shape needs to be correct to matrix multiply
print(scores.shape) # (principle components, indicators)
# sns.displot(data=scores.iloc[:,0])
scores[0] = ((scores[0] - 1200) / (2800 - 1200))**2
scores[1] = (-scores[1] + 600) / 900

# the name of the axes might not be completely accurate? it's our best guess
plot2 = sns.scatterplot(y=pd.Series(scores[0]).rename("Country Productivity"),
                        x=pd.Series(scores[1]).rename("Personal wealth (distorted by inequality)"), legend=False, ax=ax2)
plt.title("Principal Component Visualization")
# ax = sns.displot(data=scores[0])
cursor(plot2, hover=True).connect("add", lambda sel: sel.annotation.set_text(df2.index[sel.index])) # add cursor hover
plt.show()
# Out:
# (4, 221)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Percentage each indicator contributes to the index
pd.DataFrame({"Percent":100*np.abs(x.T[0])/np.abs(x.T[0]).sum(), "Value": x.T[0]}, index=df2.columns).sort_values(ascending=False, by="Percent").head(10) # Country Productivity
# pd.Series(scores[0], index=df2.index).sort_values().to_dict()
# Out:
#                                                       Percent       Value
# Indicator Name
# Cause of death, by non-communicable diseases (%...  10.337021  110.070310
# Wage and salaried workers, male (% of male empl...   8.452371   90.002253
# Wage and salaried workers, total (% of total em...   8.074317   85.976672
# Wage and salaried workers, female (% of female ...   7.546476   80.356124
# Women who were first married by age 18 (% of wo...   3.698596   39.383261
# Compensation of employees (current LCU)              1.544440   16.445456
# Compensation of employees (current LCU), FIRST ...   1.342262   14.292630
# Compulsory education, duration (years)               1.268850   13.510928
# Adjusted savings: education expenditure (curren...   1.250137   13.311663
# Adjusted savings: education expenditure (curren...   1.009790   10.752415

# %%
pd.DataFrame({"Percent":100*np.abs(x.T[1])/np.abs(x.T[1]).sum(), "Value": -x.T[1]}, index=df2.columns).sort_values(ascending=False, by="Percent").head(10) # Personal wealth (distorted by inequality)
# Out:
#                                                       Percent      Value
# Indicator Name
# Women who were first married by age 18 (% of wo...  11.172679 -36.154393
# Wage and salaried workers, female (% of female ...   7.254800  23.476277
# Wage and salaried workers, total (% of total em...   4.068380  13.165135
# Compensation of employees (current LCU)              2.734822  -8.849789
# Women who were first married by age 15 (% of wo...   2.733113  -8.844256
# Cause of death, by non-communicable diseases (%...   2.622606  -8.486660
# Compensation of employees (current LCU), FIRST ...   2.477356  -8.016637
# Births attended by skilled health staff (% of t...   2.322135  -7.514347
# Adjusted savings: education expenditure (curren...   1.927543  -6.237462
# Compulsory education, duration (years)               1.688306  -5.463300

# %%
print(pca.explained_variance_ratio_) # how much of data does the pca explain?
# Out:
# [0.87572969 0.06357132 0.01399742 0.00982442]

# %%
# import the necessary packages
import matplotlib.patches as mpatches
import geopandas as gpd
from thefuzz import process

fig3, ax3 = plt.subplots(figsize=(12, 8))

# geopandas stopped supporting built-in datasets :(
world = gpd.read_file("https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip").set_index("ADMIN")

# world map outline
world.plot(
    ax=ax3,
    color="lightgray",
    edgecolor="black",
    alpha=0.5
)

score_series = pd.Series(-scores[1], index=df2.index)
colors = sns.color_palette("magma", as_cmap=True)
colored_countries = gpd.GeoDataFrame(columns=['geometry', 'score'])
# patches = []

for i in range(len(score_series)):
    # fuzzy match country labels from the SAP dataset to the geographic data
    match = process.extractOne(score_series.index[i], world.index) # (country name, confidence)
    if match[1] < 50: # less than 50% certainty
        continue
    country_geometry = world.loc[match[0]].geometry
    score = ((score_series.iloc[i] - 1200) / (2800 - 1200))**2
    colored_countries.loc[match[0]] = {
        'geometry': country_geometry,
        'score': score
    }
    # color = colors(((score - 1200) / (2800 - 1200))**2)
    # patch = mpatches.Patch(label=match[0], color=color)
    # patches.append(patch)

# plot country colours
if not colored_countries.empty:
    colored_countries.plot(
        ax=ax3,
        column='score',
        cmap=colors,
        alpha=0.5
    )

# turn off axis ticks
ax3.set_xticks([])
ax3.set_yticks([])

plt.title("Principal Component Visualization")
# Out:
# Text(0.5, 1.0, 'Principal Component Visualization')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# # DO NOT RUN unless you want all the other charts to not show up
# # save normalization data as separate files
# import matplotlib
# matplotlib.use('Agg')
# def plot_row(row):
#     filename = ''.join([i if ord(i) < 128 and i != '/' else ' ' for i in row.name]) # make filename safe
#     ax = sns.displot(data=list(row))
#     plt.title("\n".join(textwrap.wrap(row.name + " (normalized)", 50)))
#     plt.savefig("graphs/" + filename + ".png", bbox_inches='tight')
#     plt.clf()

# # show how successful the normalization was
# df2.T.apply(plot_row, axis=1)
# !zip -r graphs.zip ./graphs
