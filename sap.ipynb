# %%
# !pip install -r requirements.txt

# %%
# %matplotlib ipympl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("SAP Datasets.xlsx")
df = df.dropna(how="all", subset=map(lambda n:str(n), range(2000, 2024))) # remove statistic if all time-series columns are null
df = df.drop(columns=["Country Code", "short description", "long description", "Indicator Code", "Unit of measure"]) # irrelevent / null columns
df
# Out:
#        Country Name                            Indicator Name  \
# 0             Aruba           Control of Corruption: Estimate
# 2       Afghanistan           Control of Corruption: Estimate
# 4            Angola           Control of Corruption: Estimate
# 5           Albania           Control of Corruption: Estimate
# 6           Andorra           Control of Corruption: Estimate
# ...             ...                                       ...
# 23135         Samoa  Urban population (% of total population)
# 23137   Yemen, Rep.  Urban population (% of total population)
# 23138  South Africa  Urban population (% of total population)
# 23139        Zambia  Urban population (% of total population)
# 23140      Zimbabwe  Urban population (% of total population)
#
#                                       Topic       2000    2001       2002  \
# 0      Public Sector: Policy & institutions        NaN     NaN        NaN
# 2      Public Sector: Policy & institutions  -1.271724     NaN  -1.251137
# 4      Public Sector: Policy & institutions  -1.197514     NaN  -1.155493
# 5      Public Sector: Policy & institutions  -0.855564     NaN  -0.845341
# 6      Public Sector: Policy & institutions   1.313404     NaN   1.310744
# ...                                     ...        ...     ...        ...
# 23135   Environment: Density & urbanization  21.977000  22.068  21.941000
# 23137   Environment: Density & urbanization  26.267000  26.787  27.315000
# 23138   Environment: Density & urbanization  56.891000  57.368  57.898000
# 23139   Environment: Density & urbanization  34.802000  35.002  35.475000
# 23140   Environment: Density & urbanization  33.758000  34.170  34.585000
#
#             2003       2004       2005       2006  ...       2014       2015  \
# 0            NaN   1.165965   1.269663   1.251313  ...   1.014232   1.248461
# 2      -1.344180  -1.350647  -1.447252  -1.446292  ...  -1.364743  -1.354240
# 4      -1.335463  -1.377569  -1.323182  -1.241038  ...  -1.457798  -1.427323
# 5      -0.853787  -0.723732  -0.813264  -0.790545  ...  -0.586141  -0.544385
# 6       1.332790   1.119150   1.269663   1.251313  ...   1.220709   1.151811
# ...          ...        ...        ...        ...  ...        ...        ...
# 23135  21.698000  21.457000  21.218000  20.981000  ...  19.149000  18.914000
# 23137  27.849000  28.390000  28.936000  29.490000  ...  34.165000  34.777000
# 23138  58.446000  58.993000  59.536000  60.077000  ...  64.312000  64.828000
# 23139  35.951000  36.430000  36.911000  37.395000  ...  41.382000  41.907000
# 23140  34.479000  34.294000  34.110000  33.926000  ...  32.504000  32.385000
#
#             2016       2017       2018       2019       2020       2021  \
# 0       1.232735   1.239377   1.207429   1.174703   1.199392   0.801611
# 2      -1.540353  -1.531910  -1.502881  -1.419499  -1.493700  -1.152327
# 4      -1.483337  -1.444333  -1.199251  -1.058418  -0.938673  -0.651610
# 5      -0.471469  -0.480891  -0.545840  -0.563900  -0.572924  -0.576536
# 6       1.159556   1.171758   1.179166   1.176592   1.266005   1.279872
# ...          ...        ...        ...        ...        ...        ...
# 23135  18.681000  18.452000  18.243000  18.056000  17.889000  17.742000
# 23137  35.394000  36.016000  36.642000  37.273000  37.908000  38.546000
# 23138  65.341000  65.850000  66.355000  66.856000  67.354000  67.847000
# 23139  42.438000  42.976000  43.521000  44.072000  44.629000  45.192000
# 23140  32.296000  32.237000  32.209000  32.210000  32.242000  32.303000
#
#             2022    2023
# 0       0.756785     NaN
# 2      -1.183776     NaN
# 4      -0.601941     NaN
# 5      -0.407876     NaN
# 6       1.270204     NaN
# ...          ...     ...
# 23135  17.616000  17.508
# 23137  39.188000  39.831
# 23138  68.335000  68.819
# 23139  45.761000  46.335
# 23140  32.395000  32.517
#
# [16699 rows x 27 columns]

# %%
from mplcursors import cursor
# sns.set_theme(rc={'figure.figsize':(20,20)})
plt.clf()

# plot poverty rates from known indicators
UNDP = np.log10(df.loc[df["Indicator Name"] == "Multidimensional poverty headcount ratio (UNDP) (% of population)"]
         .set_index("Country Name").iloc[:,7:]
         .apply(lambda row: row[row.last_valid_index()], axis=1)
         .rename("UNDP")+1)

WB = np.log10(df.loc[df["Indicator Name"] == "Multidimensional poverty headcount ratio (World Bank) (% of population)"]
        .set_index("Country Name").iloc[:,7:]
        .apply(lambda row: row[row.last_valid_index()], axis=1)
        .rename("WB")+1)

UNDP_aligned, WB_aligned = UNDP.align(WB, join='inner')
UNDP_clean = UNDP_aligned.dropna()
WB_clean = WB_aligned.dropna()

ax = sns.scatterplot(x=UNDP_clean, y=WB_clean, legend=False)

# for country in UNDP_clean.index:
#     ax.text(x=(UNDP_clean[country]+0.01), 
#             y=(WB_clean[country]-0.004), 
#             s=country, 
#             fontsize=8, 
#             alpha=0.7)
cursor(hover=True).connect("add", lambda sel: sel.annotation.set_text(WB_clean.index[sel.index]))
plt.title("log(%) of population in poverty, World Bank vs UNDP")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# show all indicators
df["Indicator Name"].unique()

# %%
sqrt = ['Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)']
nolog = [
    'Cause of death, by non-communicable diseases (% of total)',
    'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
    'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
    'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
]
square = [
    'Access to clean fuels and technologies for cooking, rural (% of rural population)',
    'Access to clean fuels and technologies for cooking, urban (% of urban population)',
    'Access to clean fuels and technologies for cooking (% of population)',
    'Access to electricity, rural (% of rural population)',
    'Access to electricity, urban (% of urban population)',
    'Access to electricity (% of population)',
    
    'Births attended by skilled health staff (% of total)',
    'Children in employment, study and work, female (% of female children in employment, ages 7-14)',
    'Children in employment, study and work, male (% of male children in employment, ages 7-14)',
    'Children in employment, study and work (% of children in employment, ages 7-14)',
    'Children in employment, total (% of children ages 7-14)',
    'Children in employment, wage workers, male (% of male children in employment, ages 7-14)',
    'Children in employment, wage workers (% of children in employment, ages 7-14)',
    'Literacy rate, youth female (% of females ages 15-24)',
    'Literacy rate, youth (ages 15-24), gender parity index (GPI)',
    'Literacy rate, youth male (% of males ages 15-24)',
    'Literacy rate, youth total (% of people ages 15-24)',
    'Literacy rate, adult female (% of females ages 15 and above)',
    'Literacy rate, adult male (% of males ages 15 and above)',
    'Literacy rate, adult total (% of people ages 15 and above)',
    'People using at least basic drinking water services (% of population)',
    'People using safely managed drinking water services (% of population)',
    'People using at least basic sanitation services (% of population)',
    'Urban population (% of total population)',
]

# %%
epsilon = 0.01 # add a little offset because you can't log 0

# Clean Data
df2 = df.copy()
# row[row.last_valid_index()] # originally we were grabbing the last non-nan cell
years = list(map(lambda n:str(n), list(range(2000, 2024))))
summaries = ["mean_x", "mean_dx", "mean_d2x"]

# take first and second derivative of the data
df2["mean_x"] = df2[years].apply(lambda row: row.mean(), axis=1)
df2["mean_dx"] = df2[years].apply(lambda row: np.diff(row.dropna(), n=1).mean(), axis=1)
df2["mean_d2x"] = df2[years].apply(lambda row: np.diff(row.dropna(), n=2).mean(), axis=1)

# drop time series data
df2 = df2.drop(columns=years)

# use pseudo-log to normalize most statistics
pseudo_log = lambda x: np.arcsinh(x/2)/np.log(10)
allnolog = sqrt + nolog + square
logged = df2.groupby("Indicator Name").filter(lambda x: x["mean_x"].min() > 0 and x["Indicator Name"].unique()[0] not in allnolog)
df2.update(logged[summaries].replace({0: epsilon}).apply(lambda col:pseudo_log(col))) # DIRECTLY CHANGES OBJECT!!!

# use pseudo-log to normalize trade surplus / deficit
logged2 = df2.loc[df2["Indicator Name"] == "Terms of trade adjustment (constant LCU)"] # monitary statistics are usually exponential
df2.update(logged2[summaries].apply(lambda col:pseudo_log(col))) # DIRECTLY CHANGES OBJECT!!!

# use square to normalize left-skewed distributions
squared = df2.groupby("Indicator Name").filter(lambda x: x["Indicator Name"].unique()[0] in square)
df2.update((squared["mean_x"] / 100)**2) # DIRECTLY CHANGES OBJECT!!!

# generate contengency table based on normalized statistics
pivot = df2.pivot(index="Country Name", columns="Indicator Name")
df2 = pivot["mean_x"].join(pivot["mean_dx"], rsuffix=", FIRST DERIVATIVE").join(pivot["mean_d2x"], rsuffix=", SECOND DERIVATIVE")
def replacer(col):
    mean = col.mean()
    std = col.std()
    # np.random.normal(mean, std) # originally we replaced the nan's with representitive statistics that had the same mean & std
    # replace with mean if cell is nan or an outlier (z-score > 2.5)
    return col.transform(lambda x: mean if (np.isnan(x) or abs((x - mean)/std) >= 2.5) else x)
    
# delete row or column if (amount of data / 2) == nan
nan_col = df2.isna().sum().sort_values()
nan_idx = df2.isna().sum(axis=1).sort_values()
nan_col = nan_col.loc[nan_col > 130]
nan_idx = nan_idx[nan_idx > 130]
df2 = df2.drop(columns=nan_col.index, index=nan_idx.index).apply(replacer)

# thing = df2.isnull().any()
# thing[thing == True]
print(df2.isnull().values.any()) 
df2

# df2.columns.to_list()
# pivot["mean_d2x"]
# Out:
# /tmp/ipykernel_2821610/3865372527.py:11: RuntimeWarning: Mean of empty slice.
#   df2["mean_dx"] = df2[years].apply(lambda row: np.diff(row.dropna(), n=1).mean(), axis=1)
# /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /tmp/ipykernel_2821610/3865372527.py:12: RuntimeWarning: Mean of empty slice.
#   df2["mean_d2x"] = df2[years].apply(lambda row: np.diff(row.dropna(), n=2).mean(), axis=1)
# /home/hhwl/miniforge3/envs/cxc/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# False
# Indicator Name              Access to clean fuels and technologies for cooking (% of population)  \
# Country Name
# Afghanistan                                                          0.044448
# Africa Western and Central                                           0.009573
# Albania                                                              0.425189
# Algeria                                                              0.978207
# Angola                                                               0.205406
# ...                                                                       ...
# West Bank and Gaza                                                   0.522369
# World                                                                0.356941
# Yemen, Rep.                                                          0.317777
# Zambia                                                               0.019588
# Zimbabwe                                                             0.096883
#
# Indicator Name              Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# Country Name
# Afghanistan                                                          0.006470
# Africa Western and Central                                           0.000540
# Albania                                                              0.205899
# Algeria                                                              0.943897
# Angola                                                               0.005763
# ...                                                                       ...
# West Bank and Gaza                                                   0.439294
# World                                                                0.120514
# Yemen, Rep.                                                          0.159513
# Zambia                                                               0.000436
# Zimbabwe                                                             0.002925
#
# Indicator Name              Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# Country Name
# Afghanistan                                                          0.425189
# Africa Western and Central                                           0.041347
# Albania                                                              0.706623
# Algeria                                                              0.997740
# Angola                                                               0.607485
# ...                                                                       ...
# West Bank and Gaza                                                   0.636055
# World                                                                0.680017
# Yemen, Rep.                                                          0.858644
# Zambia                                                               0.108484
# Zimbabwe                                                             0.669017
#
# Indicator Name              Access to electricity (% of population)  \
# Country Name
# Afghanistan                                                0.325942
# Africa Western and Central                                 0.197104
# Albania                                                    0.994529
# Algeria                                                    0.981995
# Angola                                                     0.131674
# ...                                                             ...
# West Bank and Gaza                                         0.994269
# World                                                      0.718562
# Yemen, Rep.                                                0.387154
# Zambia                                                     0.086871
# Zimbabwe                                                   0.160418
#
# Indicator Name              Access to electricity, rural (% of rural population)  \
# Country Name
# Afghanistan                                                          0.316406
# Africa Western and Central                                           0.045300
# Albania                                                              0.999131
# Algeria                                                              0.959804
# Angola                                                               0.001537
# ...                                                                       ...
# West Bank and Gaza                                                   0.986222
# World                                                                0.556290
# Yemen, Rep.                                                          0.226836
# Zambia                                                               0.005929
# Zimbabwe                                                             0.030443
#
# Indicator Name              Access to electricity, urban (% of urban population)  \
# Country Name
# Afghanistan                                                          0.782840
# Africa Western and Central                                           0.605991
# Albania                                                              0.975285
# Algeria                                                              0.993142
# Angola                                                               0.382139
# ...                                                                       ...
# West Bank and Gaza                                                   0.997132
# World                                                                0.924997
# Yemen, Rep.                                                          0.878213
# Zambia                                                               0.376409
# Zimbabwe                                                             0.733629
#
# Indicator Name              Adjusted net national income per capita (current US$)  \
# Country Name
# Afghanistan                                                          2.702385
# Africa Western and Central                                           3.060213
# Albania                                                              3.504623
# Algeria                                                              3.460934
# Angola                                                               3.186075
# ...                                                                       ...
# West Bank and Gaza                                                   3.536888
# World                                                                3.871600
# Yemen, Rep.                                                          2.882514
# Zambia                                                               2.917476
# Zimbabwe                                                             2.866943
#
# Indicator Name              Adjusted savings: education expenditure (current US$)  \
# Country Name
# Afghanistan                                                          8.695612
# Africa Western and Central                                           9.086672
# Albania                                                              8.530759
# Algeria                                                              9.793755
# Angola                                                               9.310128
# ...                                                                       ...
# West Bank and Gaza                                                   8.679404
# World                                                                9.086672
# Yemen, Rep.                                                          8.927542
# Zambia                                                               8.676742
# Zimbabwe                                                             8.444791
#
# Indicator Name              Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# Country Name
# Afghanistan                                                          2.057893
# Africa Western and Central                                           2.087651
# Albania                                                              1.236911
# Algeria                                                              1.036264
# Angola                                                               2.199554
# ...                                                                       ...
# West Bank and Gaza                                                   1.761598
# World                                                                1.709903
# Yemen, Rep.                                                          1.893741
# Zambia                                                               2.127874
# Zimbabwe                                                             2.013007
#
# Indicator Name              Adolescents out of school (% of lower secondary school age)  \
# Country Name
# Afghanistan                                                          0.922540
# Africa Western and Central                                           0.922540
# Albania                                                              0.438939
# Algeria                                                              0.488767
# Angola                                                               1.325245
# ...                                                                       ...
# West Bank and Gaza                                                   0.965890
# World                                                                0.922540
# Yemen, Rep.                                                          1.594273
# Zambia                                                               0.922540
# Zimbabwe                                                             1.257741
#
# Indicator Name              ...  \
# Country Name                ...
# Afghanistan                 ...
# Africa Western and Central  ...
# Albania                     ...
# Algeria                     ...
# Angola                      ...
# ...                         ...
# West Bank and Gaza          ...
# World                       ...
# Yemen, Rep.                 ...
# Zambia                      ...
# Zimbabwe                    ...
#
# Indicator Name              Terms of trade adjustment (constant LCU), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                          8.713281
# Africa Western and Central                                           1.445672
# Albania                                                              9.120155
# Algeria                                                              9.859411
# Angola                                                              -9.580800
# ...                                                                       ...
# West Bank and Gaza                                                   6.134218
# World                                                                1.445672
# Yemen, Rep.                                                         -8.638857
# Zambia                                                               8.918997
# Zimbabwe                                                             8.058335
#
# Indicator Name              Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.000263
# Africa Western and Central                                          -0.008555
# Albania                                                             -0.033684
# Algeria                                                             -0.003684
# Angola                                                              -0.107368
# ...                                                                       ...
# West Bank and Gaza                                                  -0.000168
# World                                                               -0.026870
# Yemen, Rep.                                                          0.000842
# Zambia                                                              -0.012105
# Zimbabwe                                                            -0.050526
#
# Indicator Name              Unemployment with advanced education (% of total labor force with advanced education), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.796659
# Africa Western and Central                                          -0.051611
# Albania                                                             -0.058822
# Algeria                                                             -0.051611
# Angola                                                               0.393280
# ...                                                                       ...
# West Bank and Gaza                                                  -0.062529
# World                                                               -0.051611
# Yemen, Rep.                                                         -0.051611
# Zambia                                                              -0.101312
# Zimbabwe                                                            -0.260459
#
# Indicator Name              Unemployment with basic education (% of total labor force with basic education), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.684209
# Africa Western and Central                                          -0.012649
# Albania                                                             -0.061096
# Algeria                                                             -0.012649
# Angola                                                              -0.012649
# ...                                                                       ...
# West Bank and Gaza                                                  -0.155708
# World                                                               -0.012649
# Yemen, Rep.                                                         -0.012649
# Zambia                                                               0.422493
# Zimbabwe                                                             0.124939
#
# Indicator Name              Unemployment with intermediate education (% of total labor force with intermediate education), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.683001
# Africa Western and Central                                          -0.002303
# Albania                                                             -0.021380
# Algeria                                                             -0.002303
# Angola                                                               0.374428
# ...                                                                       ...
# West Bank and Gaza                                                  -0.115051
# World                                                               -0.002303
# Yemen, Rep.                                                         -0.002303
# Zambia                                                              -0.144131
# Zimbabwe                                                             0.336266
#
# Indicator Name              Unemployment, total (% of total labor force) (national estimate), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.266725
# Africa Western and Central                                          -0.560774
# Albania                                                              0.001998
# Algeria                                                              0.057754
# Angola                                                               0.002892
# ...                                                                       ...
# West Bank and Gaza                                                  -0.130765
# World                                                               -0.025190
# Yemen, Rep.                                                         -0.148137
# Zambia                                                              -0.047115
# Zimbabwe                                                            -0.023386
#
# Indicator Name              Urban population (% of total population), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                          0.010273
# Africa Western and Central                                          -0.000902
# Albania                                                              0.005000
# Algeria                                                             -0.013500
# Angola                                                              -0.026364
# ...                                                                       ...
# West Bank and Gaza                                                   0.003227
# World                                                               -0.000454
# Yemen, Rep.                                                          0.005591
# Zambia                                                               0.017000
# Zimbabwe                                                            -0.013182
#
# Indicator Name              Wage and salaried workers, female (% of female employment) (modeled ILO estimate), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                          0.011234
# Africa Western and Central                                           0.023686
# Albania                                                             -0.009037
# Algeria                                                             -0.021531
# Angola                                                               0.044966
# ...                                                                       ...
# West Bank and Gaza                                                   0.010404
# World                                                               -0.012473
# Yemen, Rep.                                                          0.073033
# Zambia                                                               0.019565
# Zimbabwe                                                             0.026693
#
# Indicator Name              Wage and salaried workers, male (% of male employment) (modeled ILO estimate), SECOND DERIVATIVE  \
# Country Name
# Afghanistan                                                         -0.035012
# Africa Western and Central                                          -0.019933
# Albania                                                             -0.021626
# Algeria                                                             -0.000328
# Angola                                                              -0.028461
# ...                                                                       ...
# West Bank and Gaza                                                  -0.004707
# World                                                               -0.026413
# Yemen, Rep.                                                          0.020520
# Zambia                                                               0.023079
# Zimbabwe                                                             0.014262
#
# Indicator Name              Wage and salaried workers, total (% of total employment) (modeled ILO estimate), SECOND DERIVATIVE
# Country Name
# Afghanistan                                                          0.025683
# Africa Western and Central                                          -0.000189
# Albania                                                             -0.016342
# Algeria                                                             -0.004633
# Angola                                                               0.013800
# ...                                                                       ...
# West Bank and Gaza                                                   0.003398
# World                                                               -0.020991
# Yemen, Rep.                                                          0.007065
# Zambia                                                               0.030909
# Zimbabwe                                                             0.023292
#
# [221 rows x 201 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from mplcursors import cursor

# Do PCA
Scaled_data = StandardScaler().fit_transform(df2.T) # PCA expects the features to be on the index
pca = PCA(n_components=4) # we don't be using the last two
x = pca.fit_transform(Scaled_data)
scores = np.matmul(Scaled_data.T, x).T # shape needs to be correct to matrix multiply
print(scores.shape) # (principle components, indicators)
# sns.displot(data=scores.iloc[:,0])

plt.clf()
# the name of the axes might not be completely accurate? it's our best guess
ax = sns.scatterplot(x=pd.Series(scores[0]).rename("Country Rich?"), y=pd.Series(-scores[1]).rename("People Rich?"), legend=False)
# ax = sns.displot(data=scores[0])
cursor(hover=True).connect("add", lambda sel: sel.annotation.set_text(df2.index[sel.index])) # add cursor hover
plt.show()
# Out:
# (4, 221)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Sort the weights given to each feature in the index (higher = more important)
pd.Series(np.abs(x.T[0]), index=df2.columns).sort_values(ascending=False).to_dict() # Country rich?
# pd.Series(scores[0], index=df2.index).sort_values().to_dict()
# Out:
# {'Cause of death, by non-communicable diseases (% of total)': 106.95959703033357,
#  'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)': 87.65921845957479,
#  'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)': 84.34003492190752,
#  'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)': 79.57971708907881,
#  'Women who were first married by age 18 (% of women ages 20-24)': 36.01900690727123,
#  'Multidimensional poverty headcount ratio (World Bank) (% of population)': 29.693606792057647,
#  'Compensation of employees (current LCU)': 15.301657892708667,
#  'Compensation of employees (current LCU), FIRST DERIVATIVE': 13.255406429270138,
#  'Compulsory education, duration (years)': 12.657393185188322,
#  'Adjusted savings: education expenditure (current US$)': 12.405886120335957,
#  'Adjusted savings: education expenditure (current US$), FIRST DERIVATIVE': 9.977223183611718,
#  'Adjusted savings: education expenditure (current US$), SECOND DERIVATIVE': 7.724538892073329,
#  'Cause of death, by non-communicable diseases (% of total), SECOND DERIVATIVE': 6.996603120130843,
#  'International migrant stock, total': 6.443733096504294,
#  'Women who were first married by age 15 (% of women ages 20-24)': 5.641190425235779,
#  'Terms of trade adjustment (constant LCU)': 5.276678523330477,
#  'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)': 5.273283928805561,
#  'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total), FIRST DERIVATIVE': 4.602474247293338,
#  'Children out of school, primary, female, FIRST DERIVATIVE': 4.535545322362959,
#  'Children out of school, primary, FIRST DERIVATIVE': 4.527388380876209,
#  'Children out of school, primary': 4.521187804858553,
#  'Children out of school, primary, female': 4.1365508376536955,
#  'Children out of school, primary, male': 4.1203332893210325,
#  'Children out of school, primary, male, FIRST DERIVATIVE': 4.11893341900946,
#  'Adolescent fertility rate (births per 1,000 women ages 15-19), FIRST DERIVATIVE': 4.096635962716957,
#  'Control of Corruption: Estimate': 4.078313858825012,
#  'Political Stability and Absence of Violence/Terrorism: Estimate': 4.045317968744927,
#  'Adolescents out of school, female (% of female lower secondary school age), FIRST DERIVATIVE': 3.9585408518339698,
#  'Pregnant women receiving prenatal care (%), SECOND DERIVATIVE': 3.954871087022045,
#  'Age dependency ratio, young (% of working-age population), FIRST DERIVATIVE': 3.9382491348872093,
#  'Adolescents out of school (% of lower secondary school age), FIRST DERIVATIVE': 3.900115770953481,
#  'Children out of school, female (% of female primary school age), FIRST DERIVATIVE': 3.895219000605478,
#  'Compensation of employees (current LCU), SECOND DERIVATIVE': 3.894235084465618,
#  'Adolescents out of school, male (% of male lower secondary school age), FIRST DERIVATIVE': 3.88692598827158,
#  'Age dependency ratio (% of working-age population), FIRST DERIVATIVE': 3.882224356074036,
#  'Children out of school (% of primary school age), FIRST DERIVATIVE': 3.854806577743853,
#  'Expenditure on primary education (% of government expenditure on education), FIRST DERIVATIVE': 3.8490548699358635,
#  'Children out of school, male (% of male primary school age), FIRST DERIVATIVE': 3.843066776847911,
#  'Multilateral debt service (% of public and publicly guaranteed debt service), FIRST DERIVATIVE': 3.8387427074452076,
#  'Birth rate, crude (per 1,000 people), FIRST DERIVATIVE': 3.8339469287889054,
#  'Proportion of people living below 50 percent of median income (%), FIRST DERIVATIVE': 3.8284249147621043,
#  'Access to electricity, rural (% of rural population), SECOND DERIVATIVE': 3.822274020653594,
#  'Cause of death, by injury (% of total), SECOND DERIVATIVE': 3.815107732681348,
#  'Unemployment with basic education (% of total labor force with basic education), FIRST DERIVATIVE': 3.8120098553744026,
#  'Unemployment with advanced education (% of total labor force with advanced education), SECOND DERIVATIVE': 3.808947924466961,
#  'Unemployment, total (% of total labor force) (national estimate), FIRST DERIVATIVE': 3.778073565929226,
#  'Unemployment with intermediate education (% of total labor force with intermediate education), FIRST DERIVATIVE': 3.7758936572926896,
#  'Expenditure on secondary education (% of government expenditure on education), SECOND DERIVATIVE': 3.7716869458748605,
#  'Compensation of employees (% of expense), FIRST DERIVATIVE': 3.767701304335695,
#  'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age), SECOND DERIVATIVE': 3.7506121469296096,
#  'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age), FIRST DERIVATIVE': 3.7450073635364194,
#  'Compensation of employees (% of expense), SECOND DERIVATIVE': 3.7428084987985843,
#  'Access to electricity (% of population), SECOND DERIVATIVE': 3.7403085433930285,
#  'Access to clean fuels and technologies for cooking, urban (% of urban population), SECOND DERIVATIVE': 3.735326387066045,
#  'Unemployment with basic education (% of total labor force with basic education), SECOND DERIVATIVE': 3.7344690908418325,
#  'Multilateral debt service (% of public and publicly guaranteed debt service), SECOND DERIVATIVE': 3.73148189381682,
#  'Wage and salaried workers, male (% of male employment) (modeled ILO estimate), SECOND DERIVATIVE': 3.731116002890431,
#  'Adolescents out of school, female (% of female lower secondary school age), SECOND DERIVATIVE': 3.730988601487784,
#  'Political Stability and Absence of Violence/Terrorism: Estimate, FIRST DERIVATIVE': 3.7275750926207962,
#  'People using at least basic drinking water services (% of population), SECOND DERIVATIVE': 3.7263958168195233,
#  'People using safely managed drinking water services (% of population), SECOND DERIVATIVE': 3.726119684134775,
#  'People using at least basic sanitation services (% of population), SECOND DERIVATIVE': 3.7254100536968906,
#  'Control of Corruption: Estimate, FIRST DERIVATIVE': 3.724231126115112,
#  'Current health expenditure (% of GDP), SECOND DERIVATIVE': 3.7225866816631394,
#  'Adolescents out of school, male (% of male lower secondary school age), SECOND DERIVATIVE': 3.7221917994657234,
#  'Unemployment, total (% of total labor force) (national estimate), SECOND DERIVATIVE': 3.7216852616893004,
#  'Compulsory education, duration (years), SECOND DERIVATIVE': 3.7207319052187953,
#  'Employers, male (% of male employment) (modeled ILO estimate), SECOND DERIVATIVE': 3.720316198415106,
#  'Employers, total (% of total employment) (modeled ILO estimate), SECOND DERIVATIVE': 3.720151528873772,
#  'Employers, female (% of female employment) (modeled ILO estimate), SECOND DERIVATIVE': 3.7200708820077,
#  'Adolescents out of school (% of lower secondary school age), SECOND DERIVATIVE': 3.719917038466361,
#  'Birth rate, crude (per 1,000 people), SECOND DERIVATIVE': 3.719904566162687,
#  'School enrollment, primary (gross), gender parity index (GPI), SECOND DERIVATIVE': 3.7196607613287935,
#  'Literacy rate, youth (ages 15-24), gender parity index (GPI)': 3.7193881808355123,
#  'School enrollment, secondary (gross), gender parity index (GPI), SECOND DERIVATIVE': 3.719386831162421,
#  'School enrollment, tertiary (gross), gender parity index (GPI), SECOND DERIVATIVE': 3.718803495293716,
#  'Control of Corruption: Estimate, SECOND DERIVATIVE': 3.7186546277176196,
#  'School enrollment, primary (gross), gender parity index (GPI), FIRST DERIVATIVE': 3.7181744018925795,
#  'School enrollment, secondary (gross), gender parity index (GPI), FIRST DERIVATIVE': 3.717286188123051,
#  'Political Stability and Absence of Violence/Terrorism: Estimate, SECOND DERIVATIVE': 3.717014627879468,
#  'Employers, male (% of male employment) (modeled ILO estimate), FIRST DERIVATIVE': 3.7168956453843265,
#  'Employers, total (% of total employment) (modeled ILO estimate), FIRST DERIVATIVE': 3.7167090686039437,
#  'Age dependency ratio, old (% of working-age population), SECOND DERIVATIVE': 3.716036881073095,
#  'Adolescent fertility rate (births per 1,000 women ages 15-19), SECOND DERIVATIVE': 3.715513898935044,
#  'Urban population (% of total population), SECOND DERIVATIVE': 3.715449812741864,
#  'Access to electricity, urban (% of urban population), SECOND DERIVATIVE': 3.7150629698264876,
#  'School enrollment, tertiary (gross), gender parity index (GPI), FIRST DERIVATIVE': 3.715014965144832,
#  'Access to clean fuels and technologies for cooking (% of population), SECOND DERIVATIVE': 3.7148465566662567,
#  'Employers, female (% of female employment) (modeled ILO estimate), FIRST DERIVATIVE': 3.7139807232343953,
#  'Age dependency ratio, young (% of working-age population), SECOND DERIVATIVE': 3.713975596588287,
#  'Wage and salaried workers, total (% of total employment) (modeled ILO estimate), SECOND DERIVATIVE': 3.7130560527221803,
#  'Literacy rate, youth (ages 15-24), gender parity index (GPI), SECOND DERIVATIVE': 3.7120097377483705,
#  'Age dependency ratio (% of working-age population), SECOND DERIVATIVE': 3.711223171964704,
#  'Cause of death, by injury (% of total), FIRST DERIVATIVE': 3.7017166555990313,
#  'Proportion of people living below 50 percent of median income (%), SECOND DERIVATIVE': 3.701669925629298,
#  'Expenditure on tertiary education (% of government expenditure on education), FIRST DERIVATIVE': 3.7011841497411444,
#  'Literacy rate, youth (ages 15-24), gender parity index (GPI), FIRST DERIVATIVE': 3.6966839621541014,
#  'Access to clean fuels and technologies for cooking, rural (% of rural population), SECOND DERIVATIVE': 3.6962162634092506,
#  'Unemployment with advanced education (% of total labor force with advanced education), FIRST DERIVATIVE': 3.6933051424284966,
#  'Current health expenditure (% of GDP), FIRST DERIVATIVE': 3.6921678858514224,
#  'Wage and salaried workers, female (% of female employment) (modeled ILO estimate), SECOND DERIVATIVE': 3.6912660804442936,
#  'Expenditure on secondary education (% of government expenditure on education), FIRST DERIVATIVE': 3.6909667317603696,
#  'Unemployment with intermediate education (% of total labor force with intermediate education), SECOND DERIVATIVE': 3.6853266063869206,
#  'Expenditure on tertiary education (% of government expenditure on education), SECOND DERIVATIVE': 3.681447695976473,
#  'Children out of school, male (% of male primary school age), SECOND DERIVATIVE': 3.679212579621309,
#  'Children out of school (% of primary school age), SECOND DERIVATIVE': 3.67042090407848,
#  'Children out of school, female (% of female primary school age), SECOND DERIVATIVE': 3.6673011772624498,
#  'Age dependency ratio, old (% of working-age population), FIRST DERIVATIVE': 3.664863260511344,
#  'Expenditure on primary education (% of government expenditure on education), SECOND DERIVATIVE': 3.6475828591875223,
#  'Compulsory education, duration (years), FIRST DERIVATIVE': 3.6291622489540263,
#  'Wage and salaried workers, male (% of male employment) (modeled ILO estimate), FIRST DERIVATIVE': 3.3615528756597794,
#  'School enrollment, secondary (gross), gender parity index (GPI)': 3.3572343969659624,
#  'School enrollment, primary (gross), gender parity index (GPI)': 3.356775695283708,
#  'School enrollment, tertiary (gross), gender parity index (GPI)': 3.3526477533821093,
#  'Wage and salaried workers, total (% of total employment) (modeled ILO estimate), FIRST DERIVATIVE': 3.3080552998767874,
#  'Wage and salaried workers, female (% of female employment) (modeled ILO estimate), FIRST DERIVATIVE': 3.253138957331508,
#  'Current health expenditure per capita (current US$), SECOND DERIVATIVE': 3.170769638564779,
#  'Employers, female (% of female employment) (modeled ILO estimate)': 3.1660801423891334,
#  'Urban population (% of total population)': 3.157422120468846,
#  'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total), SECOND DERIVATIVE': 3.09776842274215,
#  'Access to clean fuels and technologies for cooking, rural (% of rural population)': 3.089054585651805,
#  'Births attended by skilled health staff (% of total), FIRST DERIVATIVE': 3.0830835458006063,
#  'Access to electricity, urban (% of urban population), FIRST DERIVATIVE': 3.043109741828356,
#  'Urban population (% of total population), FIRST DERIVATIVE': 3.04195228644618,
#  'Literacy rate, youth male (% of males ages 15-24), SECOND DERIVATIVE': 3.0028257605924784,
#  'People using safely managed drinking water services (% of population), FIRST DERIVATIVE': 2.971363062007319,
#  'Access to clean fuels and technologies for cooking (% of population)': 2.93750393171655,
#  'People using at least basic drinking water services (% of population), FIRST DERIVATIVE': 2.934241425865088,
#  'People using safely managed drinking water services (% of population)': 2.8840118237549377,
#  'Employers, total (% of total employment) (modeled ILO estimate)': 2.8609927264177633,
#  'Access to clean fuels and technologies for cooking, urban (% of urban population), FIRST DERIVATIVE': 2.8433258163569897,
#  'Literacy rate, youth total (% of people ages 15-24), SECOND DERIVATIVE': 2.8326236281531503,
#  'People using at least basic sanitation services (% of population)': 2.817237381946978,
#  'Births attended by skilled health staff (% of total), SECOND DERIVATIVE': 2.7964146246377535,
#  'Pregnant women receiving prenatal care (%), FIRST DERIVATIVE': 2.7809603863360235,
#  'Access to electricity, rural (% of rural population)': 2.7478409216402078,
#  'Access to clean fuels and technologies for cooking, urban (% of urban population)': 2.7131087478940206,
#  'Access to clean fuels and technologies for cooking, rural (% of rural population), FIRST DERIVATIVE': 2.6960103301646585,
#  'Employers, male (% of male employment) (modeled ILO estimate)': 2.6829034821482467,
#  'Literacy rate, adult female (% of females ages 15 and above)': 2.648907982186917,
#  'Children out of school, primary, female, SECOND DERIVATIVE': 2.6453732464751902,
#  'Access to clean fuels and technologies for cooking (% of population), FIRST DERIVATIVE': 2.635788243414457,
#  'Children out of school, primary, male, SECOND DERIVATIVE': 2.6243093791469527,
#  'People using at least basic sanitation services (% of population), FIRST DERIVATIVE': 2.611549328704103,
#  'Literacy rate, youth female (% of females ages 15-24), SECOND DERIVATIVE': 2.6100117036768786,
#  'Access to electricity (% of population)': 2.5983319427531146,
#  'Births attended by skilled health staff (% of total)': 2.566808855701347,
#  'Literacy rate, youth male (% of males ages 15-24), FIRST DERIVATIVE': 2.552009634125906,
#  'Literacy rate, adult total (% of people ages 15 and above)': 2.5517972395580046,
#  'People using at least basic drinking water services (% of population)': 2.485554032098148,
#  'Children out of school, primary, SECOND DERIVATIVE': 2.4499019163466604,
#  'Literacy rate, adult male (% of males ages 15 and above), SECOND DERIVATIVE': 2.438304704962406,
#  'Access to electricity (% of population), FIRST DERIVATIVE': 2.4272372966602296,
#  'Adjusted net national income per capita (current US$)': 2.4170577206155084,
#  'Literacy rate, adult male (% of males ages 15 and above)': 2.4165477276246783,
#  'Current health expenditure (% of GDP)': 2.3849373078395213,
#  'Literacy rate, adult total (% of people ages 15 and above), SECOND DERIVATIVE': 2.38176000358349,
#  'Literacy rate, youth female (% of females ages 15-24)': 2.368273913647565,
#  'Cause of death, by non-communicable diseases (% of total), FIRST DERIVATIVE': 2.3618443288300415,
#  'Access to electricity, rural (% of rural population), FIRST DERIVATIVE': 2.3403277612677007,
#  'Literacy rate, youth total (% of people ages 15-24)': 2.2962905149358765,
#  'Children out of school (% of primary school age)': 2.2866153194503696,
#  'Unemployment, total (% of total labor force) (national estimate)': 2.259602937638531,
#  'Access to electricity, urban (% of urban population)': 2.246256498649797,
#  'Literacy rate, youth male (% of males ages 15-24)': 2.242429331930406,
#  'Unemployment with advanced education (% of total labor force with advanced education)': 2.204495641301511,
#  'Literacy rate, adult female (% of females ages 15 and above), SECOND DERIVATIVE': 2.1973037456753106,
#  'Unemployment with basic education (% of total labor force with basic education)': 2.1941127997880923,
#  'Children out of school, male (% of male primary school age)': 2.180099313242581,
#  'Children out of school, female (% of female primary school age)': 2.1556019142419682,
#  'Unemployment with intermediate education (% of total labor force with intermediate education)': 2.045117397832748,
#  'Cause of death, by injury (% of total)': 2.044771370010565,
#  'Adjusted net national income per capita (current US$), SECOND DERIVATIVE': 2.0077963133343792,
#  'Age dependency ratio, old (% of working-age population)': 1.9833177034563843,
#  'Literacy rate, youth total (% of people ages 15-24), FIRST DERIVATIVE': 1.9774836670891998,
#  'Adolescents out of school (% of lower secondary school age)': 1.9565521875507872,
#  'Current health expenditure per capita (current US$), FIRST DERIVATIVE': 1.9414089787786022,
#  'Adolescents out of school, male (% of male lower secondary school age)': 1.9076000996799467,
#  'Adolescents out of school, female (% of female lower secondary school age)': 1.8780167282347309,
#  'Literacy rate, adult male (% of males ages 15 and above), FIRST DERIVATIVE': 1.771510967129272,
#  'Proportion of people living below 50 percent of median income (%)': 1.7305842663024702,
#  'Expenditure on tertiary education (% of government expenditure on education)': 1.4415331650474301,
#  'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)': 1.3827194188572067,
#  'Birth rate, crude (per 1,000 people)': 1.3105255902475548,
#  'Compensation of employees (% of expense)': 1.1142332100131742,
#  'Terms of trade adjustment (constant LCU), SECOND DERIVATIVE': 1.1077303641694296,
#  'Literacy rate, youth female (% of females ages 15-24), FIRST DERIVATIVE': 1.0371647221466418,
#  'Expenditure on secondary education (% of government expenditure on education)': 1.0143758234725646,
#  'Expenditure on primary education (% of government expenditure on education)': 0.91383111459109,
#  'Multilateral debt service (% of public and publicly guaranteed debt service)': 0.899429003700532,
#  'International migrant stock, total, FIRST DERIVATIVE': 0.8865593342302734,
#  'Literacy rate, adult total (% of people ages 15 and above), FIRST DERIVATIVE': 0.7745195288023121,
#  'Adolescent fertility rate (births per 1,000 women ages 15-19)': 0.717225840647007,
#  'Age dependency ratio, young (% of working-age population)': 0.6895025424549241,
#  'International migrant stock, total, SECOND DERIVATIVE': 0.5904998080376003,
#  'Age dependency ratio (% of working-age population)': 0.4933972288193902,
#  'Current health expenditure per capita (current US$)': 0.33680324792027,
#  'Pregnant women receiving prenatal care (%)': 0.24773824632394045,
#  'Literacy rate, adult female (% of females ages 15 and above), FIRST DERIVATIVE': 0.09770744454786953,
#  'Adjusted net national income per capita (current US$), FIRST DERIVATIVE': 0.07633986976444496,
#  'Terms of trade adjustment (constant LCU), FIRST DERIVATIVE': 0.0073536301881453655}

# %%
pd.Series(np.abs(x.T[1]), index=df2.columns).sort_values(ascending=False).to_dict() # people rich?
# Out:
# {'Multidimensional poverty headcount ratio (World Bank) (% of population)': 43.04369370776337,
#  'Women who were first married by age 18 (% of women ages 20-24)': 29.18095141044353,
#  'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)': 22.82043843397698,
#  'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)': 13.219029471518144,
#  'Women who were first married by age 15 (% of women ages 20-24)': 7.131194984649119,
#  'Compensation of employees (current LCU)': 7.014695733845957,
#  'Births attended by skilled health staff (% of total), FIRST DERIVATIVE': 6.574412861883545,
#  'Compensation of employees (current LCU), FIRST DERIVATIVE': 6.355626068062604,
#  'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)': 5.8185101421039205,
#  'Adjusted savings: education expenditure (current US$)': 4.84283898110666,
#  'Compulsory education, duration (years)': 4.046236539335193,
#  'Adjusted savings: education expenditure (current US$), FIRST DERIVATIVE': 3.987056564150937,
#  'Cause of death, by non-communicable diseases (% of total), FIRST DERIVATIVE': 3.792582874306436,
#  'Compensation of employees (current LCU), SECOND DERIVATIVE': 3.5810962897330394,
#  'Children out of school, primary': 3.43432441634756,
#  'Children out of school, primary, female': 3.321566812802888,
#  'Children out of school, primary, male': 3.19205257849157,
#  'Adjusted savings: education expenditure (current US$), SECOND DERIVATIVE': 3.1381018918875445,
#  'International migrant stock, total': 3.1101235117590043,
#  'Cause of death, by non-communicable diseases (% of total), SECOND DERIVATIVE': 2.713119906100809,
#  'Literacy rate, adult female (% of females ages 15 and above), FIRST DERIVATIVE': 2.584858746580161,
#  'Children out of school, primary, FIRST DERIVATIVE': 2.4667068544118984,
#  'Literacy rate, youth female (% of females ages 15-24), FIRST DERIVATIVE': 2.4548992062912163,
#  'Children out of school, primary, female, FIRST DERIVATIVE': 2.2045371232521025,
#  'Control of Corruption: Estimate': 1.8575519033547587,
#  'Literacy rate, adult total (% of people ages 15 and above), FIRST DERIVATIVE': 1.816860078474445,
#  'Cause of death, by non-communicable diseases (% of total)': 1.766839011706733,
#  'Political Stability and Absence of Violence/Terrorism: Estimate': 1.7565501124997496,
#  'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total), FIRST DERIVATIVE': 1.6431563311207773,
#  'Children out of school, primary, male, FIRST DERIVATIVE': 1.5796731646979811,
#  'Terms of trade adjustment (constant LCU)': 1.5564907338769614,
#  'International migrant stock, total, SECOND DERIVATIVE': 1.343312107938972,
#  'Access to clean fuels and technologies for cooking (% of population)': 1.2091741162149423,
#  'Access to electricity, rural (% of rural population)': 1.1983205158167616,
#  'Access to clean fuels and technologies for cooking, rural (% of rural population)': 1.1974646273994154,
#  'Literacy rate, youth total (% of people ages 15-24), FIRST DERIVATIVE': 1.1511919549273657,
#  'Current health expenditure per capita (current US$), FIRST DERIVATIVE': 1.1492737225227503,
#  'Access to clean fuels and technologies for cooking, urban (% of urban population)': 1.1486006536899802,
#  'People using at least basic sanitation services (% of population)': 1.1435653920987001,
#  'Adolescent fertility rate (births per 1,000 women ages 15-19), FIRST DERIVATIVE': 1.1426230901779093,
#  'Access to electricity (% of population)': 1.1139144478132852,
#  'Adjusted net national income per capita (current US$), SECOND DERIVATIVE': 1.1040492058417397,
#  'Children out of school, female (% of female primary school age), FIRST DERIVATIVE': 1.1036442331080667,
#  'Current health expenditure per capita (current US$), SECOND DERIVATIVE': 1.05570546187406,
#  'Children out of school (% of primary school age), FIRST DERIVATIVE': 1.0540224179032045,
#  'Adolescents out of school, female (% of female lower secondary school age), FIRST DERIVATIVE': 1.0320548743731177,
#  'Children out of school, male (% of male primary school age), FIRST DERIVATIVE': 1.0307130837311704,
#  'Multilateral debt service (% of public and publicly guaranteed debt service), FIRST DERIVATIVE': 1.0204795640444297,
#  'Literacy rate, adult female (% of females ages 15 and above), SECOND DERIVATIVE': 1.0043947008858571,
#  'Cause of death, by injury (% of total), SECOND DERIVATIVE': 0.9880678038117261,
#  'Births attended by skilled health staff (% of total), SECOND DERIVATIVE': 0.9849894308744609,
#  'Age dependency ratio (% of working-age population), FIRST DERIVATIVE': 0.981271101977871,
#  'Adolescents out of school (% of lower secondary school age), FIRST DERIVATIVE': 0.9777653680372425,
#  'Age dependency ratio, young (% of working-age population), FIRST DERIVATIVE': 0.9526383927249136,
#  'Births attended by skilled health staff (% of total)': 0.9511479082325415,
#  'Unemployment with basic education (% of total labor force with basic education), FIRST DERIVATIVE': 0.9429566996264424,
#  'Expenditure on primary education (% of government expenditure on education), FIRST DERIVATIVE': 0.939010456625423,
#  'Birth rate, crude (per 1,000 people), FIRST DERIVATIVE': 0.9388426711577429,
#  'Proportion of people living below 50 percent of median income (%), FIRST DERIVATIVE': 0.934303716633538,
#  'Literacy rate, adult female (% of females ages 15 and above)': 0.9328982575916412,
#  'Urban population (% of total population)': 0.922401620381871,
#  'Adolescents out of school, male (% of male lower secondary school age), FIRST DERIVATIVE': 0.9182783434293346,
#  'Access to electricity, rural (% of rural population), SECOND DERIVATIVE': 0.9163945673729113,
#  'Pregnant women receiving prenatal care (%), SECOND DERIVATIVE': 0.9140018474602039,
#  'Unemployment with advanced education (% of total labor force with advanced education), SECOND DERIVATIVE': 0.9023642431678968,
#  'Unemployment with intermediate education (% of total labor force with intermediate education), FIRST DERIVATIVE': 0.9010016910281164,
#  'Adolescent fertility rate (births per 1,000 women ages 15-19)': 0.899466790834815,
#  'Wage and salaried workers, male (% of male employment) (modeled ILO estimate), SECOND DERIVATIVE': 0.8866406152954808,
#  'Adolescents out of school, female (% of female lower secondary school age), SECOND DERIVATIVE': 0.8861511377096234,
#  'Age dependency ratio, old (% of working-age population), FIRST DERIVATIVE': 0.8854699924046604,
#  'Unemployment, total (% of total labor force) (national estimate), FIRST DERIVATIVE': 0.8814502895231721,
#  'Compensation of employees (% of expense), SECOND DERIVATIVE': 0.8812564953640156,
#  'Expenditure on secondary education (% of government expenditure on education), SECOND DERIVATIVE': 0.8785410885786582,
#  'Proportion of people living below 50 percent of median income (%), SECOND DERIVATIVE': 0.8763909877903411,
#  'People using at least basic drinking water services (% of population)': 0.8696869161831837,
#  'Compensation of employees (% of expense), FIRST DERIVATIVE': 0.8687985116348333,
#  'Adolescent fertility rate (births per 1,000 women ages 15-19), SECOND DERIVATIVE': 0.8674178774121603,
#  'Multilateral debt service (% of public and publicly guaranteed debt service), SECOND DERIVATIVE': 0.8664838329613608,
#  'Access to electricity, urban (% of urban population), SECOND DERIVATIVE': 0.8662491075554125,
#  'Age dependency ratio (% of working-age population), SECOND DERIVATIVE': 0.8660090974435701,
#  'Unemployment, total (% of total labor force) (national estimate), SECOND DERIVATIVE': 0.8653585802313171,
#  'Age dependency ratio, young (% of working-age population), SECOND DERIVATIVE': 0.8646573341466991,
#  'Political Stability and Absence of Violence/Terrorism: Estimate, FIRST DERIVATIVE': 0.8633556830710885,
#  'Adolescents out of school (% of lower secondary school age), SECOND DERIVATIVE': 0.8598357503841565,
#  'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age), SECOND DERIVATIVE': 0.8593482649015937,
#  'Current health expenditure (% of GDP), SECOND DERIVATIVE': 0.8592445564705304,
#  'Compulsory education, duration (years), SECOND DERIVATIVE': 0.8590672583572805,
#  'Birth rate, crude (per 1,000 people), SECOND DERIVATIVE': 0.8590600664996291,
#  'Age dependency ratio, old (% of working-age population), SECOND DERIVATIVE': 0.8587486163060175,
#  'Employers, female (% of female employment) (modeled ILO estimate), SECOND DERIVATIVE': 0.8576471844852789,
#  'School enrollment, primary (gross), gender parity index (GPI), SECOND DERIVATIVE': 0.8575879382099509,
#  'Control of Corruption: Estimate, SECOND DERIVATIVE': 0.8575165982109756,
#  'Literacy rate, youth (ages 15-24), gender parity index (GPI)': 0.8574709222088547,
#  'School enrollment, secondary (gross), gender parity index (GPI), SECOND DERIVATIVE': 0.8574406864850358,
#  'Employers, total (% of total employment) (modeled ILO estimate), SECOND DERIVATIVE': 0.857259246443201,
#  'People using at least basic drinking water services (% of population), SECOND DERIVATIVE': 0.8572115764671812,
#  'Control of Corruption: Estimate, FIRST DERIVATIVE': 0.8570543500263723,
#  'Employers, male (% of male employment) (modeled ILO estimate), SECOND DERIVATIVE': 0.8569749611585685,
#  'School enrollment, tertiary (gross), gender parity index (GPI), SECOND DERIVATIVE': 0.8561041796857195,
#  'People using at least basic sanitation services (% of population), SECOND DERIVATIVE': 0.8555099274329865,
#  'People using safely managed drinking water services (% of population), SECOND DERIVATIVE': 0.8552680092237801,
#  'School enrollment, primary (gross), gender parity index (GPI), FIRST DERIVATIVE': 0.8551260532320877,
#  'Wage and salaried workers, total (% of total employment) (modeled ILO estimate), SECOND DERIVATIVE': 0.8549709995903516,
#  'Current health expenditure (% of GDP), FIRST DERIVATIVE': 0.8547024374116224,
#  'School enrollment, tertiary (gross), gender parity index (GPI), FIRST DERIVATIVE': 0.8539364831283419,
#  'Political Stability and Absence of Violence/Terrorism: Estimate, SECOND DERIVATIVE': 0.8538004402481489,
#  'School enrollment, secondary (gross), gender parity index (GPI), FIRST DERIVATIVE': 0.8535127357286455,
#  'Employers, female (% of female employment) (modeled ILO estimate), FIRST DERIVATIVE': 0.8530460839082439,
#  'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age), FIRST DERIVATIVE': 0.8520519618823074,
#  'Urban population (% of total population), SECOND DERIVATIVE': 0.8517116023167931,
#  'Employers, total (% of total employment) (modeled ILO estimate), FIRST DERIVATIVE': 0.8499781817168816,
#  'Employers, male (% of male employment) (modeled ILO estimate), FIRST DERIVATIVE': 0.8489767796533702,
#  'Literacy rate, adult total (% of people ages 15 and above)': 0.8471366174044401,
#  'Access to electricity (% of population), SECOND DERIVATIVE': 0.8456561382390089,
#  'Adolescents out of school, male (% of male lower secondary school age), SECOND DERIVATIVE': 0.8451539144799302,
#  'People using safely managed drinking water services (% of population)': 0.8435638103186985,
#  'Literacy rate, youth (ages 15-24), gender parity index (GPI), SECOND DERIVATIVE': 0.8429936880802393,
#  'Compulsory education, duration (years), FIRST DERIVATIVE': 0.8408437388570419,
#  'Expenditure on tertiary education (% of government expenditure on education), SECOND DERIVATIVE': 0.8374779432979005,
#  'Access to clean fuels and technologies for cooking, urban (% of urban population), SECOND DERIVATIVE': 0.8350926505139868,
#  'Access to clean fuels and technologies for cooking, rural (% of rural population), SECOND DERIVATIVE': 0.833199975173931,
#  'Expenditure on secondary education (% of government expenditure on education), FIRST DERIVATIVE': 0.8327306589336139,
#  'Unemployment with intermediate education (% of total labor force with intermediate education), SECOND DERIVATIVE': 0.826996205275527,
#  'Literacy rate, youth (ages 15-24), gender parity index (GPI), FIRST DERIVATIVE': 0.8269651525756923,
#  'Wage and salaried workers, female (% of female employment) (modeled ILO estimate), SECOND DERIVATIVE': 0.8241322847566671,
#  'Access to clean fuels and technologies for cooking (% of population), SECOND DERIVATIVE': 0.8195603369518765,
#  'Children out of school, male (% of male primary school age), SECOND DERIVATIVE': 0.8177839540655526,
#  'School enrollment, tertiary (gross), gender parity index (GPI)': 0.8147325586678504,
#  'Children out of school (% of primary school age), SECOND DERIVATIVE': 0.8121600949880597,
#  'Expenditure on tertiary education (% of government expenditure on education), FIRST DERIVATIVE': 0.8110843822315713,
#  'Unemployment with advanced education (% of total labor force with advanced education), FIRST DERIVATIVE': 0.8094006636218004,
#  'Unemployment with basic education (% of total labor force with basic education), SECOND DERIVATIVE': 0.8037033893371645,
#  'Children out of school, female (% of female primary school age), SECOND DERIVATIVE': 0.7991869664845817,
#  'Literacy rate, adult male (% of males ages 15 and above), FIRST DERIVATIVE': 0.7805415569808655,
#  'Employers, female (% of female employment) (modeled ILO estimate)': 0.7680077715264303,
#  'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)': 0.7631441076379148,
#  'Expenditure on primary education (% of government expenditure on education), SECOND DERIVATIVE': 0.7517702323230787,
#  'Access to clean fuels and technologies for cooking, rural (% of rural population), FIRST DERIVATIVE': 0.7509163567576445,
#  'School enrollment, secondary (gross), gender parity index (GPI)': 0.7421674406947916,
#  'Literacy rate, youth female (% of females ages 15-24)': 0.7310187522571181,
#  'School enrollment, primary (gross), gender parity index (GPI)': 0.7257095623332597,
#  'Employers, total (% of total employment) (modeled ILO estimate)': 0.7244136660007003,
#  'Wage and salaried workers, male (% of male employment) (modeled ILO estimate), FIRST DERIVATIVE': 0.7068825229784179,
#  'Literacy rate, youth female (% of females ages 15-24), SECOND DERIVATIVE': 0.6933405105976669,
#  'Employers, male (% of male employment) (modeled ILO estimate)': 0.6748227480279376,
#  'Wage and salaried workers, total (% of total employment) (modeled ILO estimate), FIRST DERIVATIVE': 0.672914619394204,
#  'Age dependency ratio, young (% of working-age population)': 0.6660359697136655,
#  'Literacy rate, adult male (% of males ages 15 and above)': 0.6647947077533012,
#  'Wage and salaried workers, female (% of female employment) (modeled ILO estimate), FIRST DERIVATIVE': 0.6449097926984186,
#  'Literacy rate, adult total (% of people ages 15 and above), SECOND DERIVATIVE': 0.6346871221988933,
#  'Adjusted net national income per capita (current US$)': 0.6312619981613888,
#  'Access to electricity, urban (% of urban population)': 0.6203640155782125,
#  'Cause of death, by injury (% of total), FIRST DERIVATIVE': 0.6148415019144698,
#  'Age dependency ratio (% of working-age population)': 0.612694676929412,
#  'Literacy rate, youth total (% of people ages 15-24)': 0.5981434395602613,
#  'Literacy rate, youth male (% of males ages 15-24), SECOND DERIVATIVE': 0.5847736470595505,
#  'Children out of school, primary, SECOND DERIVATIVE': 0.5713980982507546,
#  'Terms of trade adjustment (constant LCU), SECOND DERIVATIVE': 0.5551366854377794,
#  'Literacy rate, youth male (% of males ages 15-24)': 0.5185039135946555,
#  'Age dependency ratio, old (% of working-age population)': 0.5066590125228155,
#  'People using safely managed drinking water services (% of population), FIRST DERIVATIVE': 0.4857489955321544,
#  'Literacy rate, youth male (% of males ages 15-24), FIRST DERIVATIVE': 0.48046475979194675,
#  'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total), SECOND DERIVATIVE': 0.4771713749650233,
#  'Adolescents out of school (% of lower secondary school age)': 0.4759633156628095,
#  'Adolescents out of school, female (% of female lower secondary school age)': 0.47289409114801134,
#  'International migrant stock, total, FIRST DERIVATIVE': 0.46540244808004594,
#  'Pregnant women receiving prenatal care (%)': 0.46201405385114086,
#  'Access to clean fuels and technologies for cooking (% of population), FIRST DERIVATIVE': 0.45747915339934975,
#  'Access to electricity (% of population), FIRST DERIVATIVE': 0.45435030567937706,
#  'Unemployment, total (% of total labor force) (national estimate)': 0.45196229399530946,
#  'Urban population (% of total population), FIRST DERIVATIVE': 0.44730297387472434,
#  'Unemployment with basic education (% of total labor force with basic education)': 0.44420040093845736,
#  'Birth rate, crude (per 1,000 people)': 0.4419835997709759,
#  'Current health expenditure (% of GDP)': 0.42396557875455154,
#  'Terms of trade adjustment (constant LCU), FIRST DERIVATIVE': 0.412900602855695,
#  'Multilateral debt service (% of public and publicly guaranteed debt service)': 0.4026600668212688,
#  'Adolescents out of school, male (% of male lower secondary school age)': 0.40111025821240837,
#  'Literacy rate, adult male (% of males ages 15 and above), SECOND DERIVATIVE': 0.3904133493353333,
#  'Expenditure on primary education (% of government expenditure on education)': 0.38849110701901246,
#  'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)': 0.3688840301542992,
#  'Current health expenditure per capita (current US$)': 0.3033629425853818,
#  'Children out of school, female (% of female primary school age)': 0.29721600060740094,
#  'Adjusted net national income per capita (current US$), FIRST DERIVATIVE': 0.292744327316362,
#  'Pregnant women receiving prenatal care (%), FIRST DERIVATIVE': 0.2871315483981548,
#  'Children out of school (% of primary school age)': 0.2523909988435246,
#  'Compensation of employees (% of expense)': 0.25172732887426813,
#  'Children out of school, male (% of male primary school age)': 0.2149963051702437,
#  'Access to clean fuels and technologies for cooking, urban (% of urban population), FIRST DERIVATIVE': 0.20432198204153565,
#  'People using at least basic sanitation services (% of population), FIRST DERIVATIVE': 0.19243957184221316,
#  'Unemployment with intermediate education (% of total labor force with intermediate education)': 0.17936797796891088,
#  'Cause of death, by injury (% of total)': 0.14595259108045047,
#  'Literacy rate, youth total (% of people ages 15-24), SECOND DERIVATIVE': 0.1422606670558045,
#  'Expenditure on secondary education (% of government expenditure on education)': 0.14084937223568728,
#  'People using at least basic drinking water services (% of population), FIRST DERIVATIVE': 0.11443171499383155,
#  'Access to electricity, urban (% of urban population), FIRST DERIVATIVE': 0.11367619727995494,
#  'Children out of school, primary, female, SECOND DERIVATIVE': 0.09863980661117498,
#  'Unemployment with advanced education (% of total labor force with advanced education)': 0.09845041976133789,
#  'Proportion of people living below 50 percent of median income (%)': 0.05451194227716452,
#  'Children out of school, primary, male, SECOND DERIVATIVE': 0.05069132964599962,
#  'Expenditure on tertiary education (% of government expenditure on education)': 0.025915301521254916,
#  'Access to electricity, rural (% of rural population), FIRST DERIVATIVE': 0.004471654289537003}

# %%
print(pca.explained_variance_ratio_) # how much of data does the pca explain?
# Out:
# [0.84785579 0.08796667 0.01757731 0.00874323]

# %%
# DO NOT RUN unless you want all the other charts to not show up
import matplotlib
matplotlib.use('Agg')
def plot_row(row):
    filename = ''.join([i if ord(i) < 128 and i != '/' else ' ' for i in row.name])
    sns.displot(data=row.rename(row.name + " (normalized)"))
    plt.savefig("graphs/" + filename + ".png")
    plt.clf()

# show how successful the normalization was
df2.T.apply(plot_row, axis=1)
# !zip -r graphs.zip ./graphs
# Out:
#   adding: graphs/ (stored 0%)
#   adding: graphs/Current health expenditure per capita (current US$), FIRST DERIVATIVE.png (deflated 19%)
#   adding: graphs/Children out of school, female (% of female primary school age), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Unemployment with intermediate education (% of total labor force with intermediate education).png (deflated 17%)
#   adding: graphs/Access to clean fuels and technologies for cooking, urban (% of urban population).png (deflated 18%)
#   adding: graphs/Literacy rate, youth (ages 15-24), gender parity index (GPI).png (deflated 17%)
#   adding: graphs/Compensation of employees (% of expense).png (deflated 19%)
#   adding: graphs/Births attended by skilled health staff (% of total), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Children out of school, primary, female.png (deflated 19%)
#   adding: graphs/Literacy rate, adult female (% of females ages 15 and above), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Adolescent fertility rate (births per 1,000 women ages 15-19).png (deflated 18%)
#   adding: graphs/Births attended by skilled health staff (% of total).png (deflated 18%)
#   adding: graphs/Adolescent fertility rate (births per 1,000 women ages 15-19), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Unemployment with intermediate education (% of total labor force with intermediate education), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Wage and salaried workers, male (% of male employment) (modeled ILO estimate), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Current health expenditure per capita (current US$), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/People using at least basic drinking water services (% of population).png (deflated 18%)
#   adding: graphs/Compensation of employees (% of expense), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Literacy rate, youth total (% of people ages 15-24).png (deflated 17%)
#   adding: graphs/Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of^Jtotal).png (deflated 18%)
#   adding: graphs/Employers, total (% of total employment) (modeled ILO estimate), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Access to electricity (% of population).png (deflated 18%)
#   adding: graphs/Unemployment with intermediate education (% of total labor force with intermediate education), FIRST^JDERIVATIVE.png (deflated 18%)
#   adding: graphs/Literacy rate, adult total (% of people ages 15 and above), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Control of Corruption: Estimate, SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Adolescents out of school, female (% of female lower secondary school age), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Children out of school, primary, male.png (deflated 19%)
#   adding: graphs/Children out of school, male (% of male primary school age), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Compensation of employees (% of expense), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Access to electricity, rural (% of rural population), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Literacy rate, adult total (% of people ages 15 and above), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Access to clean fuels and technologies for cooking, urban (% of urban population), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Access to clean fuels and technologies for cooking (% of population), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Political Stability and Absence of Violence Terrorism: Estimate, FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/School enrollment, secondary (gross), gender parity index (GPI), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Expenditure on secondary education (% of government expenditure on education), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Employers, male (% of male employment) (modeled ILO estimate), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Age dependency ratio, old (% of working-age population).png (deflated 19%)
#   adding: graphs/Age dependency ratio (% of working-age population).png (deflated 18%)
#   adding: graphs/Access to clean fuels and technologies for cooking (% of population), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Children out of school (% of primary school age), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Control of Corruption: Estimate, FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Proportion of people living below 50 percent of median income (%), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Adolescents out of school (% of lower secondary school age), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Terms of trade adjustment (constant LCU), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Literacy rate, youth total (% of people ages 15-24), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/School enrollment, primary (gross), gender parity index (GPI), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Unemployment with advanced education (% of total labor force with advanced education), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Wage and salaried workers, total (% of total employment) (modeled ILO estimate), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Unemployment with advanced education (% of total labor force with advanced education), FIRST^JDERIVATIVE.png (deflated 16%)
#   adding: graphs/Multilateral debt service (% of public and publicly guaranteed debt service).png (deflated 18%)
#   adding: graphs/Access to clean fuels and technologies for cooking, rural (% of rural population).png (deflated 18%)
#   adding: graphs/Unemployment with basic education (% of total labor force with basic education).png (deflated 18%)
#   adding: graphs/Unemployment with basic education (% of total labor force with basic education), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Children out of school, female (% of female primary school age), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Adolescents out of school, male (% of male lower secondary school age), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Access to clean fuels and technologies for cooking, rural (% of rural population), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Literacy rate, adult female (% of females ages 15 and above), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Terms of trade adjustment (constant LCU).png (deflated 19%)
#   adding: graphs/Children out of school, male (% of male primary school age), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of^Jtotal), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Unemployment with advanced education (% of total labor force with advanced education), SECOND^JDERIVATIVE.png (deflated 18%)
#   adding: graphs/School enrollment, tertiary (gross), gender parity index (GPI), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Wage and salaried workers, total (% of total employment) (modeled ILO estimate).png (deflated 18%)
#   adding: graphs/Employers, female (% of female employment) (modeled ILO estimate), SECOND DERIVATIVE.png (deflated 16%)
#   adding: graphs/School enrollment, secondary (gross), gender parity index (GPI), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Wage and salaried workers, total (% of total employment) (modeled ILO estimate), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Age dependency ratio, young (% of working-age population).png (deflated 17%)
#   adding: graphs/Adjusted net national income per capita (current US$), SECOND DERIVATIVE.png (deflated 18%)
#  (deflated 18%)s/People using safely managed drinking water services (% of population).png
#   adding: graphs/Children out of school, primary, male, SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Access to electricity, urban (% of urban population).png (deflated 17%)
#   adding: graphs/Literacy rate, adult male (% of males ages 15 and above), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/People using at least basic drinking water services (% of population), SECOND DERIVATIVE.png (deflated 16%)
#   adding: graphs/Pregnant women receiving prenatal care (%).png (deflated 18%)
#   adding: graphs/Literacy rate, youth male (% of males ages 15-24), FIRST DERIVATIVE.png (deflated 19%)
#   adding: graphs/Adjusted net national income per capita (current US$), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Employers, total (% of total employment) (modeled ILO estimate).png (deflated 19%)
#   adding: graphs/Unemployment with basic education (% of total labor force with basic education), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Age dependency ratio, old (% of working-age population), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Access to electricity (% of population), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Compensation of employees (current LCU), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Unemployment, total (% of total labor force) (national estimate), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/People using at least basic drinking water services (% of population), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Multilateral debt service (% of public and publicly guaranteed debt service), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Age dependency ratio (% of working-age population), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Proportion of people living below 50 percent of median income (%).png (deflated 17%)
#   adding: graphs/Birth rate, crude (per 1,000 people), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Unemployment with advanced education (% of total labor force with advanced education).png (deflated 18%)
#   adding: graphs/Cause of death, by injury (% of total), SECOND DERIVATIVE.png (deflated 16%)
#   adding: graphs/Expenditure on tertiary education (% of government expenditure on education), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Adolescent fertility rate (births per 1,000 women ages 15-19), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Expenditure on primary education (% of government expenditure on education).png (deflated 18%)
#   adding: graphs/Women who were first married by age 18 (% of women ages 20-24).png (deflated 18%)
#   adding: graphs/Adolescents out of school, female (% of female lower secondary school age).png (deflated 17%)
#   adding: graphs/Current health expenditure (% of GDP), FIRST DERIVATIVE.png (deflated 16%)
#   adding: graphs/Access to electricity (% of population), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Cause of death, by non-communicable diseases (% of total).png (deflated 19%)
#   adding: graphs/Adjusted savings: education expenditure (current US$), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Adolescents out of school, female (% of female lower secondary school age), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Children out of school (% of primary school age), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Wage and salaried workers, female (% of female employment) (modeled ILO estimate), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Children out of school, primary, SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Birth rate, crude (per 1,000 people), SECOND DERIVATIVE.png (deflated 16%)
#   adding: graphs/International migrant stock, total.png (deflated 20%)
#   adding: graphs/Adjusted savings: education expenditure (current US$).png (deflated 17%)
#   adding: graphs/School enrollment, tertiary (gross), gender parity index (GPI).png (deflated 18%)
#   adding: graphs/Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Terms of trade adjustment (constant LCU), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/People using at least basic sanitation services (% of population).png (deflated 18%)
#   adding: graphs/Cause of death, by injury (% of total).png (deflated 18%)
#   adding: graphs/Children out of school, male (% of male primary school age).png (deflated 18%)
#   adding: graphs/Expenditure on primary education (% of government expenditure on education), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Children out of school (% of primary school age).png (deflated 18%)
#   adding: graphs/Urban population (% of total population), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Access to electricity, urban (% of urban population), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Urban population (% of total population), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Access to clean fuels and technologies for cooking (% of population).png (deflated 18%)
#   adding: graphs/Access to electricity, urban (% of urban population), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Wage and salaried workers, male (% of male employment) (modeled ILO estimate).png (deflated 18%)
#   adding: graphs/Proportion of people living below 50 percent of median income (%), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Children out of school, primary.png (deflated 19%)
#   adding: graphs/Children out of school, primary, female, FIRST DERIVATIVE.png (deflated 19%)
#   adding: graphs/School enrollment, primary (gross), gender parity index (GPI).png (deflated 17%)
#   adding: graphs/Compulsory education, duration (years).png (deflated 17%)
#   adding: graphs/People using at least basic sanitation services (% of population), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Literacy rate, adult male (% of males ages 15 and above), SECOND DERIVATIVE.png (deflated 19%)
#   adding: graphs/Children out of school, female (% of female primary school age).png (deflated 17%)
#   adding: graphs/Multilateral debt service (% of public and publicly guaranteed debt service), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Employers, male (% of male employment) (modeled ILO estimate), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Employers, female (% of female employment) (modeled ILO estimate), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Unemployment with intermediate education (% of total labor force with intermediate education), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Women who were first married by age 15 (% of women ages 20-24).png (deflated 17%)
#   adding: graphs/Adjusted net national income per capita (current US$).png (deflated 19%)
#   adding: graphs/Multidimensional poverty headcount ratio (World Bank) (% of population).png (deflated 18%)
#   adding: graphs/Expenditure on tertiary education (% of government expenditure on education).png (deflated 17%)
#   adding: graphs/Wage and salaried workers, female (% of female employment) (modeled ILO estimate).png (deflated 17%)
#   adding: graphs/Literacy rate, youth female (% of females ages 15-24), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of^Jage), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Pregnant women receiving prenatal care (%), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Literacy rate, youth (ages 15-24), gender parity index (GPI), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Cause of death, by non-communicable diseases (% of total), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Literacy rate, youth male (% of males ages 15-24), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Political Stability and Absence of Violence Terrorism: Estimate, SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Literacy rate, youth male (% of males ages 15-24).png (deflated 18%)
#   adding: graphs/Unemployment, total (% of total labor force) (national estimate).png (deflated 19%)
#  (deflated 17%)s/Births attended by skilled health staff (% of total), SECOND DERIVATIVE.png
#   adding: graphs/Access to clean fuels and technologies for cooking, urban (% of urban population), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Access to electricity, rural (% of rural population).png (deflated 19%)
#   adding: graphs/Age dependency ratio (% of working-age population), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Adolescents out of school, male (% of male lower secondary school age), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/School enrollment, tertiary (gross), gender parity index (GPI), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Age dependency ratio, young (% of working-age population), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Compensation of employees (current LCU).png (deflated 17%)
#   adding: graphs/Current health expenditure per capita (current US$).png (deflated 18%)
#   adding: graphs/Children out of school, primary, male, FIRST DERIVATIVE.png (deflated 20%)
#   adding: graphs/Age dependency ratio, young (% of working-age population), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Expenditure on secondary education (% of government expenditure on education), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Birth rate, crude (per 1,000 people).png (deflated 18%)
#   adding: graphs/Employers, female (% of female employment) (modeled ILO estimate).png (deflated 17%)
#   adding: graphs/International migrant stock, total, SECOND DERIVATIVE.png (deflated 19%)
#   adding: graphs/Adjusted savings: education expenditure (current US$), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of^Jage), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/International migrant stock, total, FIRST DERIVATIVE.png (deflated 19%)
#   adding: graphs/Control of Corruption: Estimate.png (deflated 18%)
#   adding: graphs/Literacy rate, youth (ages 15-24), gender parity index (GPI), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Current health expenditure (% of GDP).png (deflated 18%)
#   adding: graphs/Cause of death, by injury (% of total), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/School enrollment, primary (gross), gender parity index (GPI), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Children out of school, primary, female, SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Expenditure on secondary education (% of government expenditure on education).png (deflated 18%)
#   adding: graphs/Access to electricity, rural (% of rural population), SECOND DERIVATIVE.png (deflated 16%)
#   adding: graphs/Expenditure on tertiary education (% of government expenditure on education), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Literacy rate, adult female (% of females ages 15 and above).png (deflated 18%)
#   adding: graphs/People using at least basic sanitation services (% of population), SECOND DERIVATIVE.png (deflated 16%)
#   adding: graphs/Literacy rate, adult total (% of people ages 15 and above).png (deflated 18%)
#   adding: graphs/Pregnant women receiving prenatal care (%), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/.ipynb_checkpoints/ (stored 0%)
#   adding: graphs/Adolescents out of school (% of lower secondary school age).png (deflated 18%)
#   adding: graphs/People using safely managed drinking water services (% of population), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Literacy rate, youth female (% of females ages 15-24).png (deflated 18%)
#   adding: graphs/Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age).png (deflated 17%)
#   adding: graphs/Unemployment, total (% of total labor force) (national estimate), FIRST DERIVATIVE.png (deflated 16%)
#   adding: graphs/Urban population (% of total population).png (deflated 19%)
#   adding: graphs/School enrollment, secondary (gross), gender parity index (GPI).png (deflated 17%)
#   adding: graphs/Compulsory education, duration (years), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Wage and salaried workers, female (% of female employment) (modeled ILO estimate), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Adolescents out of school (% of lower secondary school age), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of^Jtotal), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Access to clean fuels and technologies for cooking, rural (% of rural population), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Children out of school, primary, FIRST DERIVATIVE.png (deflated 19%)
#   adding: graphs/Adolescents out of school, male (% of male lower secondary school age).png (deflated 18%)
#   adding: graphs/Expenditure on primary education (% of government expenditure on education), FIRST DERIVATIVE.png (deflated 16%)
#   adding: graphs/Cause of death, by non-communicable diseases (% of total), SECOND DERIVATIVE.png (deflated 18%)
#   adding: graphs/Unemployment with advanced education (% of total labor force with advanced education), FIRST DERIVATIVE.png (deflated 16%)
#   adding: graphs/Unemployment with intermediate education (% of total labor force with intermediate education),^JSECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Current health expenditure (% of GDP), SECOND DERIVATIVE.png (deflated 16%)
#   adding: graphs/Literacy rate, youth total (% of people ages 15-24), FIRST DERIVATIVE.png (deflated 16%)
#   adding: graphs/Compensation of employees (current LCU), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Literacy rate, adult male (% of males ages 15 and above).png (deflated 18%)
#   adding: graphs/Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total).png (deflated 18%)
#   adding: graphs/Literacy rate, youth female (% of females ages 15-24), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Employers, male (% of male employment) (modeled ILO estimate).png (deflated 18%)
#   adding: graphs/Age dependency ratio, old (% of working-age population), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/Political Stability and Absence of Violence Terrorism: Estimate.png (deflated 18%)
#   adding: graphs/Compulsory education, duration (years), FIRST DERIVATIVE.png (deflated 18%)
#   adding: graphs/Wage and salaried workers, male (% of male employment) (modeled ILO estimate), SECOND DERIVATIVE.png (deflated 17%)
#   adding: graphs/Employers, total (% of total employment) (modeled ILO estimate), FIRST DERIVATIVE.png (deflated 17%)
#   adding: graphs/People using safely managed drinking water services (% of population), FIRST DERIVATIVE.png (deflated 17%)
